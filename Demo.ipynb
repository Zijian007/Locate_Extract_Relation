# %% [markdown]
# # Prepatation

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import json
from dotenv import load_dotenv
load_dotenv(".env")
import torch
from util.utils import ModelAndTokenizer, plot_scores, find_token_range
from util.causal_trace import plot_all_flow

torch.set_grad_enabled(False)
# Out:
# /home/zijianwang/miniconda3/envs/EasyEdit/lib/python3.9/site-packages/transformers/utils/hub.py:124: FutureWarning: Using `TRANSFORMERS_CACHE` is deprecated and will be removed in v5 of Transformers. Use `HF_HOME` instead.
#   warnings.warn(

# %%
model_name = "mistralai/Mistral-7B-Instruct-v0.1"  
device = "cuda:1"
mt = ModelAndTokenizer(model_name, device)
# Out:
# /home/zijianwang/miniconda3/envs/EasyEdit/lib/python3.9/site-packages/huggingface_hub/file_download.py:1150: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /home/zijianwang/miniconda3/envs/EasyEdit/lib/python3.9/site-packages/huggingface_hub/file_download.py:1150: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %% [markdown]
# ## 1.Location by Causal Mediation Analysis

# %%
id = 8
data_path = "data/country_capital_city.json"
with open(data_path, 'r') as file:
    data = json.load(file)
Template = data["Prompt"]
Template_zs = data["prompt_templates_zs"]
relation = data["Relation"]
subject = data["samples"][id]["subject"]
object = data["samples"][id]["object"]
print(f"Subject: {subject}, Relation: {relation}, Object: {object}")
print(Template)
print(Template_zs)
# Out:
# Subject: Venezuela, Relation: capital city of this country, Object: Caracas
# Given {}, the capital city of this country is
# Given {},

# %%
Recall_prompt = Template.format(subject)
token_range_sub = find_token_range(mt.tokenizer, Recall_prompt, subject)
token_range_rel = find_token_range(mt.tokenizer, Recall_prompt, relation)
# token_range_rel[1] = token_range_rel[1] + 3

res_dict_no_rel = plot_all_flow(mt, Recall_prompt, subject = None, noise = 1, type = None, noise_range = token_range_rel)
print("--------------------------------------------------")
res_dict_no_sub  = plot_all_flow(mt, Recall_prompt, subject = None, noise = 1, type = None, noise_range = token_range_sub)
# Out:
# Tokens: ['<s>', ' Given', ' Venezuela', ',', ' the', ' capital', ' city', ' of', ' this', ' country', ' is']
# Tokens: ['<s>', ' Given', ' Venezuela', ',', ' the', ' capital', ' city', ' of', ' this', ' country', ' is']
# Plotting hs...
# inp_ids=tensor([    1, 12628, 25307, 28725,   272,  5565,  2990,   302,   456,  2939,
#           349], device='cuda:1')
# inp_tokens: {0: '<s>', 1: '▁Given', 2: '▁Venezuela', 3: ',', 4: '▁the', 5: '▁capital', 6: '▁city', 7: '▁of', 8: '▁this', 9: '▁country', 10: '▁is'}
# Answer is Car, Answer_id is 2364, Answer_token: ['▁Car'], base_score is 0.9436522722244263
# noise_range : [5, 10]
# Tracing 0/11 ,0/32
# Tracing 0/11 ,1/32
# Tracing 0/11 ,2/32
# Tracing 0/11 ,3/32
# Tracing 0/11 ,4/32
# Tracing 0/11 ,5/32
# Tracing 0/11 ,6/32
# Tracing 0/11 ,7/32
# Tracing 0/11 ,8/32
# Tracing 0/11 ,9/32
# Tracing 0/11 ,10/32
# Tracing 0/11 ,11/32
# Tracing 0/11 ,12/32
# Tracing 0/11 ,13/32
# Tracing 0/11 ,14/32
# Tracing 0/11 ,15/32
# Tracing 0/11 ,16/32
# Tracing 0/11 ,17/32
# Tracing 0/11 ,18/32
# Tracing 0/11 ,19/32
# Tracing 0/11 ,20/32
# Tracing 0/11 ,21/32
# Tracing 0/11 ,22/32
# Tracing 0/11 ,23/32
# Tracing 0/11 ,24/32
# Tracing 0/11 ,25/32
# Tracing 0/11 ,26/32
# Tracing 0/11 ,27/32
# Tracing 0/11 ,28/32
# Tracing 0/11 ,29/32
# Tracing 0/11 ,30/32
# Tracing 0/11 ,31/32
# Tracing 1/11 ,0/32
# Tracing 1/11 ,1/32
# Tracing 1/11 ,2/32
# Tracing 1/11 ,3/32
# Tracing 1/11 ,4/32
# Tracing 1/11 ,5/32
# Tracing 1/11 ,6/32
# Tracing 1/11 ,7/32
# Tracing 1/11 ,8/32
# Tracing 1/11 ,9/32
# Tracing 1/11 ,10/32
# Tracing 1/11 ,11/32
# Tracing 1/11 ,12/32
# Tracing 1/11 ,13/32
# Tracing 1/11 ,14/32
# Tracing 1/11 ,15/32
# Tracing 1/11 ,16/32
# Tracing 1/11 ,17/32
# Tracing 1/11 ,18/32
# Tracing 1/11 ,19/32
# Tracing 1/11 ,20/32
# Tracing 1/11 ,21/32
# Tracing 1/11 ,22/32
# Tracing 1/11 ,23/32
# Tracing 1/11 ,24/32
# Tracing 1/11 ,25/32
# Tracing 1/11 ,26/32
# Tracing 1/11 ,27/32
# Tracing 1/11 ,28/32
# Tracing 1/11 ,29/32
# Tracing 1/11 ,30/32
# Tracing 1/11 ,31/32
# Tracing 2/11 ,0/32
# Tracing 2/11 ,1/32
# Tracing 2/11 ,2/32
# Tracing 2/11 ,3/32
# Tracing 2/11 ,4/32
# Tracing 2/11 ,5/32
# Tracing 2/11 ,6/32
# Tracing 2/11 ,7/32
# Tracing 2/11 ,8/32
# Tracing 2/11 ,9/32
# Tracing 2/11 ,10/32
# Tracing 2/11 ,11/32
# Tracing 2/11 ,12/32
# Tracing 2/11 ,13/32
# Tracing 2/11 ,14/32
# Tracing 2/11 ,15/32
# Tracing 2/11 ,16/32
# Tracing 2/11 ,17/32
# Tracing 2/11 ,18/32
# Tracing 2/11 ,19/32
# Tracing 2/11 ,20/32
# Tracing 2/11 ,21/32
# Tracing 2/11 ,22/32
# Tracing 2/11 ,23/32
# Tracing 2/11 ,24/32
# Tracing 2/11 ,25/32
# Tracing 2/11 ,26/32
# Tracing 2/11 ,27/32
# Tracing 2/11 ,28/32
# Tracing 2/11 ,29/32
# Tracing 2/11 ,30/32
# Tracing 2/11 ,31/32
# Tracing 3/11 ,0/32
# Tracing 3/11 ,1/32
# Tracing 3/11 ,2/32
# Tracing 3/11 ,3/32
# Tracing 3/11 ,4/32
# Tracing 3/11 ,5/32
# Tracing 3/11 ,6/32
# Tracing 3/11 ,7/32
# Tracing 3/11 ,8/32
# Tracing 3/11 ,9/32
# Tracing 3/11 ,10/32
# Tracing 3/11 ,11/32
# Tracing 3/11 ,12/32
# Tracing 3/11 ,13/32
# Tracing 3/11 ,14/32
# Tracing 3/11 ,15/32
# Tracing 3/11 ,16/32
# Tracing 3/11 ,17/32
# Tracing 3/11 ,18/32
# Tracing 3/11 ,19/32
# Tracing 3/11 ,20/32
# Tracing 3/11 ,21/32
# Tracing 3/11 ,22/32
# Tracing 3/11 ,23/32
# Tracing 3/11 ,24/32
# Tracing 3/11 ,25/32
# Tracing 3/11 ,26/32
# Tracing 3/11 ,27/32
# Tracing 3/11 ,28/32
# Tracing 3/11 ,29/32
# Tracing 3/11 ,30/32
# Tracing 3/11 ,31/32
# Tracing 4/11 ,0/32
# Tracing 4/11 ,1/32
# Tracing 4/11 ,2/32
# Tracing 4/11 ,3/32
# Tracing 4/11 ,4/32
# Tracing 4/11 ,5/32
# Tracing 4/11 ,6/32
# Tracing 4/11 ,7/32
# Tracing 4/11 ,8/32
# Tracing 4/11 ,9/32
# Tracing 4/11 ,10/32
# Tracing 4/11 ,11/32
# Tracing 4/11 ,12/32
# Tracing 4/11 ,13/32
# Tracing 4/11 ,14/32
# Tracing 4/11 ,15/32
# Tracing 4/11 ,16/32
# Tracing 4/11 ,17/32
# Tracing 4/11 ,18/32
# Tracing 4/11 ,19/32
# Tracing 4/11 ,20/32
# Tracing 4/11 ,21/32
# Tracing 4/11 ,22/32
# Tracing 4/11 ,23/32
# Tracing 4/11 ,24/32
# Tracing 4/11 ,25/32
# Tracing 4/11 ,26/32
# Tracing 4/11 ,27/32
# Tracing 4/11 ,28/32
# Tracing 4/11 ,29/32
# Tracing 4/11 ,30/32
# Tracing 4/11 ,31/32
# Tracing 5/11 ,0/32
# Tracing 5/11 ,1/32
# Tracing 5/11 ,2/32
# Tracing 5/11 ,3/32
# Tracing 5/11 ,4/32
# Tracing 5/11 ,5/32
# Tracing 5/11 ,6/32
# Tracing 5/11 ,7/32
# Tracing 5/11 ,8/32
# Tracing 5/11 ,9/32
# Tracing 5/11 ,10/32
# Tracing 5/11 ,11/32
# Tracing 5/11 ,12/32
# Tracing 5/11 ,13/32
# Tracing 5/11 ,14/32
# Tracing 5/11 ,15/32
# Tracing 5/11 ,16/32
# Tracing 5/11 ,17/32
# Tracing 5/11 ,18/32
# Tracing 5/11 ,19/32
# Tracing 5/11 ,20/32
# Tracing 5/11 ,21/32
# Tracing 5/11 ,22/32
# Tracing 5/11 ,23/32
# Tracing 5/11 ,24/32
# Tracing 5/11 ,25/32
# Tracing 5/11 ,26/32
# Tracing 5/11 ,27/32
# Tracing 5/11 ,28/32
# Tracing 5/11 ,29/32
# Tracing 5/11 ,30/32
# Tracing 5/11 ,31/32
# Tracing 6/11 ,0/32
# Tracing 6/11 ,1/32
# Tracing 6/11 ,2/32
# Tracing 6/11 ,3/32
# Tracing 6/11 ,4/32
# Tracing 6/11 ,5/32
# Tracing 6/11 ,6/32
# Tracing 6/11 ,7/32
# Tracing 6/11 ,8/32
# Tracing 6/11 ,9/32
# Tracing 6/11 ,10/32
# Tracing 6/11 ,11/32
# Tracing 6/11 ,12/32
# Tracing 6/11 ,13/32
# Tracing 6/11 ,14/32
# Tracing 6/11 ,15/32
# Tracing 6/11 ,16/32
# Tracing 6/11 ,17/32
# Tracing 6/11 ,18/32
# Tracing 6/11 ,19/32
# Tracing 6/11 ,20/32
# Tracing 6/11 ,21/32
# Tracing 6/11 ,22/32
# Tracing 6/11 ,23/32
# Tracing 6/11 ,24/32
# Tracing 6/11 ,25/32
# Tracing 6/11 ,26/32
# Tracing 6/11 ,27/32
# Tracing 6/11 ,28/32
# Tracing 6/11 ,29/32
# Tracing 6/11 ,30/32
# Tracing 6/11 ,31/32
# Tracing 7/11 ,0/32
# Tracing 7/11 ,1/32
# Tracing 7/11 ,2/32
# Tracing 7/11 ,3/32
# Tracing 7/11 ,4/32
# Tracing 7/11 ,5/32
# Tracing 7/11 ,6/32
# Tracing 7/11 ,7/32
# Tracing 7/11 ,8/32
# Tracing 7/11 ,9/32
# Tracing 7/11 ,10/32
# Tracing 7/11 ,11/32
# Tracing 7/11 ,12/32
# Tracing 7/11 ,13/32
# Tracing 7/11 ,14/32
# Tracing 7/11 ,15/32
# Tracing 7/11 ,16/32
# Tracing 7/11 ,17/32
# Tracing 7/11 ,18/32
# Tracing 7/11 ,19/32
# Tracing 7/11 ,20/32
# Tracing 7/11 ,21/32
# Tracing 7/11 ,22/32
# Tracing 7/11 ,23/32
# Tracing 7/11 ,24/32
# Tracing 7/11 ,25/32
# Tracing 7/11 ,26/32
# Tracing 7/11 ,27/32
# Tracing 7/11 ,28/32
# Tracing 7/11 ,29/32
# Tracing 7/11 ,30/32
# Tracing 7/11 ,31/32
# Tracing 8/11 ,0/32
# Tracing 8/11 ,1/32
# Tracing 8/11 ,2/32
# Tracing 8/11 ,3/32
# Tracing 8/11 ,4/32
# Tracing 8/11 ,5/32
# Tracing 8/11 ,6/32
# Tracing 8/11 ,7/32
# Tracing 8/11 ,8/32
# Tracing 8/11 ,9/32
# Tracing 8/11 ,10/32
# Tracing 8/11 ,11/32
# Tracing 8/11 ,12/32
# Tracing 8/11 ,13/32
# Tracing 8/11 ,14/32
# Tracing 8/11 ,15/32
# Tracing 8/11 ,16/32
# Tracing 8/11 ,17/32
# Tracing 8/11 ,18/32
# Tracing 8/11 ,19/32
# Tracing 8/11 ,20/32
# Tracing 8/11 ,21/32
# Tracing 8/11 ,22/32
# Tracing 8/11 ,23/32
# Tracing 8/11 ,24/32
# Tracing 8/11 ,25/32
# Tracing 8/11 ,26/32
# Tracing 8/11 ,27/32
# Tracing 8/11 ,28/32
# Tracing 8/11 ,29/32
# Tracing 8/11 ,30/32
# Tracing 8/11 ,31/32
# Tracing 9/11 ,0/32
# Tracing 9/11 ,1/32
# Tracing 9/11 ,2/32
# Tracing 9/11 ,3/32
# Tracing 9/11 ,4/32
# Tracing 9/11 ,5/32
# Tracing 9/11 ,6/32
# Tracing 9/11 ,7/32
# Tracing 9/11 ,8/32
# Tracing 9/11 ,9/32
# Tracing 9/11 ,10/32
# Tracing 9/11 ,11/32
# Tracing 9/11 ,12/32
# Tracing 9/11 ,13/32
# Tracing 9/11 ,14/32
# Tracing 9/11 ,15/32
# Tracing 9/11 ,16/32
# Tracing 9/11 ,17/32
# Tracing 9/11 ,18/32
# Tracing 9/11 ,19/32
# Tracing 9/11 ,20/32
# Tracing 9/11 ,21/32
# Tracing 9/11 ,22/32
# Tracing 9/11 ,23/32
# Tracing 9/11 ,24/32
# Tracing 9/11 ,25/32
# Tracing 9/11 ,26/32
# Tracing 9/11 ,27/32
# Tracing 9/11 ,28/32
# Tracing 9/11 ,29/32
# Tracing 9/11 ,30/32
# Tracing 9/11 ,31/32
# Tracing 10/11 ,0/32
# Tracing 10/11 ,1/32
# Tracing 10/11 ,2/32
# Tracing 10/11 ,3/32
# Tracing 10/11 ,4/32
# Tracing 10/11 ,5/32
# Tracing 10/11 ,6/32
# Tracing 10/11 ,7/32
# Tracing 10/11 ,8/32
# Tracing 10/11 ,9/32
# Tracing 10/11 ,10/32
# Tracing 10/11 ,11/32
# Tracing 10/11 ,12/32
# Tracing 10/11 ,13/32
# Tracing 10/11 ,14/32
# Tracing 10/11 ,15/32
# Tracing 10/11 ,16/32
# Tracing 10/11 ,17/32
# Tracing 10/11 ,18/32
# Tracing 10/11 ,19/32
# Tracing 10/11 ,20/32
# Tracing 10/11 ,21/32
# Tracing 10/11 ,22/32
# Tracing 10/11 ,23/32
# Tracing 10/11 ,24/32
# Tracing 10/11 ,25/32
# Tracing 10/11 ,26/32
# Tracing 10/11 ,27/32
# Tracing 10/11 ,28/32
# Tracing 10/11 ,29/32
# Tracing 10/11 ,30/32
# Tracing 10/11 ,31/32
# --------------------------------------------------
# Plotting hs...
# inp_ids=tensor([    1, 12628, 25307, 28725,   272,  5565,  2990,   302,   456,  2939,
#           349], device='cuda:1')
# inp_tokens: {0: '<s>', 1: '▁Given', 2: '▁Venezuela', 3: ',', 4: '▁the', 5: '▁capital', 6: '▁city', 7: '▁of', 8: '▁this', 9: '▁country', 10: '▁is'}
# Answer is Car, Answer_id is 2364, Answer_token: ['▁Car'], base_score is 0.9436522722244263
# noise_range : [2, 3]
# Tracing 0/11 ,0/32
# Tracing 0/11 ,1/32
# Tracing 0/11 ,2/32
# Tracing 0/11 ,3/32
# Tracing 0/11 ,4/32
# Tracing 0/11 ,5/32
# Tracing 0/11 ,6/32
# Tracing 0/11 ,7/32
# Tracing 0/11 ,8/32
# Tracing 0/11 ,9/32
# Tracing 0/11 ,10/32
# Tracing 0/11 ,11/32
# Tracing 0/11 ,12/32
# Tracing 0/11 ,13/32
# Tracing 0/11 ,14/32
# Tracing 0/11 ,15/32
# Tracing 0/11 ,16/32
# Tracing 0/11 ,17/32
# Tracing 0/11 ,18/32
# Tracing 0/11 ,19/32
# Tracing 0/11 ,20/32
# Tracing 0/11 ,21/32
# Tracing 0/11 ,22/32
# Tracing 0/11 ,23/32
# Tracing 0/11 ,24/32
# Tracing 0/11 ,25/32
# Tracing 0/11 ,26/32
# Tracing 0/11 ,27/32
# Tracing 0/11 ,28/32
# Tracing 0/11 ,29/32
# Tracing 0/11 ,30/32
# Tracing 0/11 ,31/32
# Tracing 1/11 ,0/32
# Tracing 1/11 ,1/32
# Tracing 1/11 ,2/32
# Tracing 1/11 ,3/32
# Tracing 1/11 ,4/32
# Tracing 1/11 ,5/32
# Tracing 1/11 ,6/32
# Tracing 1/11 ,7/32
# Tracing 1/11 ,8/32
# Tracing 1/11 ,9/32
# Tracing 1/11 ,10/32
# Tracing 1/11 ,11/32
# Tracing 1/11 ,12/32
# Tracing 1/11 ,13/32
# Tracing 1/11 ,14/32
# Tracing 1/11 ,15/32
# Tracing 1/11 ,16/32
# Tracing 1/11 ,17/32
# Tracing 1/11 ,18/32
# Tracing 1/11 ,19/32
# Tracing 1/11 ,20/32
# Tracing 1/11 ,21/32
# Tracing 1/11 ,22/32
# Tracing 1/11 ,23/32
# Tracing 1/11 ,24/32
# Tracing 1/11 ,25/32
# Tracing 1/11 ,26/32
# Tracing 1/11 ,27/32
# Tracing 1/11 ,28/32
# Tracing 1/11 ,29/32
# Tracing 1/11 ,30/32
# Tracing 1/11 ,31/32
# Tracing 2/11 ,0/32
# Tracing 2/11 ,1/32
# Tracing 2/11 ,2/32
# Tracing 2/11 ,3/32
# Tracing 2/11 ,4/32
# Tracing 2/11 ,5/32
# Tracing 2/11 ,6/32
# Tracing 2/11 ,7/32
# Tracing 2/11 ,8/32
# Tracing 2/11 ,9/32
# Tracing 2/11 ,10/32
# Tracing 2/11 ,11/32
# Tracing 2/11 ,12/32
# Tracing 2/11 ,13/32
# Tracing 2/11 ,14/32
# Tracing 2/11 ,15/32
# Tracing 2/11 ,16/32
# Tracing 2/11 ,17/32
# Tracing 2/11 ,18/32
# Tracing 2/11 ,19/32
# Tracing 2/11 ,20/32
# Tracing 2/11 ,21/32
# Tracing 2/11 ,22/32
# Tracing 2/11 ,23/32
# Tracing 2/11 ,24/32
# Tracing 2/11 ,25/32
# Tracing 2/11 ,26/32
# Tracing 2/11 ,27/32
# Tracing 2/11 ,28/32
# Tracing 2/11 ,29/32
# Tracing 2/11 ,30/32
# Tracing 2/11 ,31/32
# Tracing 3/11 ,0/32
# Tracing 3/11 ,1/32
# Tracing 3/11 ,2/32
# Tracing 3/11 ,3/32
# Tracing 3/11 ,4/32
# Tracing 3/11 ,5/32
# Tracing 3/11 ,6/32
# Tracing 3/11 ,7/32
# Tracing 3/11 ,8/32
# Tracing 3/11 ,9/32
# Tracing 3/11 ,10/32
# Tracing 3/11 ,11/32
# Tracing 3/11 ,12/32
# Tracing 3/11 ,13/32
# Tracing 3/11 ,14/32
# Tracing 3/11 ,15/32
# Tracing 3/11 ,16/32
# Tracing 3/11 ,17/32
# Tracing 3/11 ,18/32
# Tracing 3/11 ,19/32
# Tracing 3/11 ,20/32
# Tracing 3/11 ,21/32
# Tracing 3/11 ,22/32
# Tracing 3/11 ,23/32
# Tracing 3/11 ,24/32
# Tracing 3/11 ,25/32
# Tracing 3/11 ,26/32
# Tracing 3/11 ,27/32
# Tracing 3/11 ,28/32
# Tracing 3/11 ,29/32
# Tracing 3/11 ,30/32
# Tracing 3/11 ,31/32
# Tracing 4/11 ,0/32
# Tracing 4/11 ,1/32
# Tracing 4/11 ,2/32
# Tracing 4/11 ,3/32
# Tracing 4/11 ,4/32
# Tracing 4/11 ,5/32
# Tracing 4/11 ,6/32
# Tracing 4/11 ,7/32
# Tracing 4/11 ,8/32
# Tracing 4/11 ,9/32
# Tracing 4/11 ,10/32
# Tracing 4/11 ,11/32
# Tracing 4/11 ,12/32
# Tracing 4/11 ,13/32
# Tracing 4/11 ,14/32
# Tracing 4/11 ,15/32
# Tracing 4/11 ,16/32
# Tracing 4/11 ,17/32
# Tracing 4/11 ,18/32
# Tracing 4/11 ,19/32
# Tracing 4/11 ,20/32
# Tracing 4/11 ,21/32
# Tracing 4/11 ,22/32
# Tracing 4/11 ,23/32
# Tracing 4/11 ,24/32
# Tracing 4/11 ,25/32
# Tracing 4/11 ,26/32
# Tracing 4/11 ,27/32
# Tracing 4/11 ,28/32
# Tracing 4/11 ,29/32
# Tracing 4/11 ,30/32
# Tracing 4/11 ,31/32
# Tracing 5/11 ,0/32
# Tracing 5/11 ,1/32
# Tracing 5/11 ,2/32
# Tracing 5/11 ,3/32
# Tracing 5/11 ,4/32
# Tracing 5/11 ,5/32
# Tracing 5/11 ,6/32
# Tracing 5/11 ,7/32
# Tracing 5/11 ,8/32
# Tracing 5/11 ,9/32
# Tracing 5/11 ,10/32
# Tracing 5/11 ,11/32
# Tracing 5/11 ,12/32
# Tracing 5/11 ,13/32
# Tracing 5/11 ,14/32
# Tracing 5/11 ,15/32
# Tracing 5/11 ,16/32
# Tracing 5/11 ,17/32
# Tracing 5/11 ,18/32
# Tracing 5/11 ,19/32
# Tracing 5/11 ,20/32
# Tracing 5/11 ,21/32
# Tracing 5/11 ,22/32
# Tracing 5/11 ,23/32
# Tracing 5/11 ,24/32
# Tracing 5/11 ,25/32
# Tracing 5/11 ,26/32
# Tracing 5/11 ,27/32
# Tracing 5/11 ,28/32
# Tracing 5/11 ,29/32
# Tracing 5/11 ,30/32
# Tracing 5/11 ,31/32
# Tracing 6/11 ,0/32
# Tracing 6/11 ,1/32
# Tracing 6/11 ,2/32
# Tracing 6/11 ,3/32
# Tracing 6/11 ,4/32
# Tracing 6/11 ,5/32
# Tracing 6/11 ,6/32
# Tracing 6/11 ,7/32
# Tracing 6/11 ,8/32
# Tracing 6/11 ,9/32
# Tracing 6/11 ,10/32
# Tracing 6/11 ,11/32
# Tracing 6/11 ,12/32
# Tracing 6/11 ,13/32
# Tracing 6/11 ,14/32
# Tracing 6/11 ,15/32
# Tracing 6/11 ,16/32
# Tracing 6/11 ,17/32
# Tracing 6/11 ,18/32
# Tracing 6/11 ,19/32
# Tracing 6/11 ,20/32
# Tracing 6/11 ,21/32
# Tracing 6/11 ,22/32
# Tracing 6/11 ,23/32
# Tracing 6/11 ,24/32
# Tracing 6/11 ,25/32
# Tracing 6/11 ,26/32
# Tracing 6/11 ,27/32
# Tracing 6/11 ,28/32
# Tracing 6/11 ,29/32
# Tracing 6/11 ,30/32
# Tracing 6/11 ,31/32
# Tracing 7/11 ,0/32
# Tracing 7/11 ,1/32
# Tracing 7/11 ,2/32
# Tracing 7/11 ,3/32
# Tracing 7/11 ,4/32
# Tracing 7/11 ,5/32
# Tracing 7/11 ,6/32
# Tracing 7/11 ,7/32
# Tracing 7/11 ,8/32
# Tracing 7/11 ,9/32
# Tracing 7/11 ,10/32
# Tracing 7/11 ,11/32
# Tracing 7/11 ,12/32
# Tracing 7/11 ,13/32
# Tracing 7/11 ,14/32
# Tracing 7/11 ,15/32
# Tracing 7/11 ,16/32
# Tracing 7/11 ,17/32
# Tracing 7/11 ,18/32
# Tracing 7/11 ,19/32
# Tracing 7/11 ,20/32
# Tracing 7/11 ,21/32
# Tracing 7/11 ,22/32
# Tracing 7/11 ,23/32
# Tracing 7/11 ,24/32
# Tracing 7/11 ,25/32
# Tracing 7/11 ,26/32
# Tracing 7/11 ,27/32
# Tracing 7/11 ,28/32
# Tracing 7/11 ,29/32
# Tracing 7/11 ,30/32
# Tracing 7/11 ,31/32
# Tracing 8/11 ,0/32
# Tracing 8/11 ,1/32
# Tracing 8/11 ,2/32
# Tracing 8/11 ,3/32
# Tracing 8/11 ,4/32
# Tracing 8/11 ,5/32
# Tracing 8/11 ,6/32
# Tracing 8/11 ,7/32
# Tracing 8/11 ,8/32
# Tracing 8/11 ,9/32
# Tracing 8/11 ,10/32
# Tracing 8/11 ,11/32
# Tracing 8/11 ,12/32
# Tracing 8/11 ,13/32
# Tracing 8/11 ,14/32
# Tracing 8/11 ,15/32
# Tracing 8/11 ,16/32
# Tracing 8/11 ,17/32
# Tracing 8/11 ,18/32
# Tracing 8/11 ,19/32
# Tracing 8/11 ,20/32
# Tracing 8/11 ,21/32
# Tracing 8/11 ,22/32
# Tracing 8/11 ,23/32
# Tracing 8/11 ,24/32
# Tracing 8/11 ,25/32
# Tracing 8/11 ,26/32
# Tracing 8/11 ,27/32
# Tracing 8/11 ,28/32
# Tracing 8/11 ,29/32
# Tracing 8/11 ,30/32
# Tracing 8/11 ,31/32
# Tracing 9/11 ,0/32
# Tracing 9/11 ,1/32
# Tracing 9/11 ,2/32
# Tracing 9/11 ,3/32
# Tracing 9/11 ,4/32
# Tracing 9/11 ,5/32
# Tracing 9/11 ,6/32
# Tracing 9/11 ,7/32
# Tracing 9/11 ,8/32
# Tracing 9/11 ,9/32
# Tracing 9/11 ,10/32
# Tracing 9/11 ,11/32
# Tracing 9/11 ,12/32
# Tracing 9/11 ,13/32
# Tracing 9/11 ,14/32
# Tracing 9/11 ,15/32
# Tracing 9/11 ,16/32
# Tracing 9/11 ,17/32
# Tracing 9/11 ,18/32
# Tracing 9/11 ,19/32
# Tracing 9/11 ,20/32
# Tracing 9/11 ,21/32
# Tracing 9/11 ,22/32
# Tracing 9/11 ,23/32
# Tracing 9/11 ,24/32
# Tracing 9/11 ,25/32
# Tracing 9/11 ,26/32
# Tracing 9/11 ,27/32
# Tracing 9/11 ,28/32
# Tracing 9/11 ,29/32
# Tracing 9/11 ,30/32
# Tracing 9/11 ,31/32
# Tracing 10/11 ,0/32
# Tracing 10/11 ,1/32
# Tracing 10/11 ,2/32
# Tracing 10/11 ,3/32
# Tracing 10/11 ,4/32
# Tracing 10/11 ,5/32
# Tracing 10/11 ,6/32
# Tracing 10/11 ,7/32
# Tracing 10/11 ,8/32
# Tracing 10/11 ,9/32
# Tracing 10/11 ,10/32
# Tracing 10/11 ,11/32
# Tracing 10/11 ,12/32
# Tracing 10/11 ,13/32
# Tracing 10/11 ,14/32
# Tracing 10/11 ,15/32
# Tracing 10/11 ,16/32
# Tracing 10/11 ,17/32
# Tracing 10/11 ,18/32
# Tracing 10/11 ,19/32
# Tracing 10/11 ,20/32
# Tracing 10/11 ,21/32
# Tracing 10/11 ,22/32
# Tracing 10/11 ,23/32
# Tracing 10/11 ,24/32
# Tracing 10/11 ,25/32
# Tracing 10/11 ,26/32
# Tracing 10/11 ,27/32
# Tracing 10/11 ,28/32
# Tracing 10/11 ,29/32
# Tracing 10/11 ,30/32
# Tracing 10/11 ,31/32

# %%
score_no_rel = res_dict_no_rel["hs"]['scores'][-1]
score_no_sub = res_dict_no_sub["hs"]['scores'][-1]
# score_no_instructs.append(score_no_instruct)
# score_no_inputs.append(score_no_input)
title = f"Mediating effect of subject and relation at last token, {Recall_prompt}"
plot_scores(score_no_rel, score_no_sub, title)

# %%
diff = torch.abs(score_no_rel - score_no_sub)
threshold = 0.4
big_diff_mask = diff > threshold
start_idx = torch.where(big_diff_mask)[0][0] if torch.any(big_diff_mask) else None
end_idx = torch.where(big_diff_mask)[0][-1]  if torch.any(big_diff_mask) else None
relational_range = (int(start_idx), int(end_idx))
if start_idx is None or end_idx is None:
    print("No Relation Emergence Stage Found (diff > threshold)!")
else:
    print(f"Relation Emergence Stage: {relational_range}")
# Out:
# Relation Emergence Stage: (5, 18)

# %% [markdown]
# ## Zero shot

# %%
from util.locating_extracting import zero_shot, edit

# %%
acc_zs, acc_full, good_cases = zero_shot(mt, data_path, Recall_prompt, layer_range = relational_range, template = Template_zs)
# Out:
# MistralModel is using MistralSdpaAttention, but `torch.nn.functional.scaled_dot_product_attention` does not support `output_attentions=True`. Falling back to the manual attention implementation, but specifying the manual implementation will be required from Transformers version v5.0.0 onwards. This warning can be removed using the argument `attn_implementation="eager"` when loading the model.
# subject:United States,object:Washington D.C.
# Input:Given Guinea-Bissau,
# progress:0/253
# Sub: Guinea-Bissau
# Result_ZS:True, ZS Obj: Bissau.</s></s>, True Obj: Bissau
# Result_Full:True, Full Obj: Bissau. This city, True Obj: Bissau
# acc_zs:0.003952569169960474, acc_full:0.003952569169960474
# --------------------------------------------------------------
# Input:Given Germany,
# progress:1/253
# Sub: Germany
# Result_ZS:True, ZS Obj: Berlin.</s></s></s></s>, True Obj: Berlin
# Result_Full:True, Full Obj: Berlin. Berlin is a city, True Obj: Berlin
# acc_zs:0.007905138339920948, acc_full:0.007905138339920948
# --------------------------------------------------------------
# Input:Given Bhutan,
# progress:2/253
# Sub: Bhutan
# Result_ZS:True, ZS Obj: Thimphu. What, True Obj: Thimphu
# Result_Full:True, Full Obj: Thimphu. Th, True Obj: Thimphu
# acc_zs:0.011857707509881422, acc_full:0.011857707509881422
# --------------------------------------------------------------
# Input:Given Sweden,
# progress:3/253
# Sub: Sweden
# Result_ZS:True, ZS Obj: Stockholm.</s></s></s></s>, True Obj: Stockholm
# Result_Full:True, Full Obj: Stockholm. Stockholm is known for, True Obj: Stockholm
# acc_zs:0.015810276679841896, acc_full:0.015810276679841896
# --------------------------------------------------------------
# Input:Given South Sudan South Sudan,
# progress:4/253
# Sub: South Sudan South Sudan
# Result_ZS:True, ZS Obj: Juba. Juba is, True Obj: Juba
# Result_Full:True, Full Obj: Juba. Juba is, True Obj: Juba
# acc_zs:0.019762845849802372, acc_full:0.019762845849802372
# --------------------------------------------------------------
# Input:Given Israel,
# progress:5/253
# Sub: Israel
# Result_ZS:True, ZS Obj: Jerusalem.
#
# Jer, True Obj: Jerusalem
# Result_Full:True, Full Obj: Jerusalem.
#
# Israel, True Obj: Jerusalem
# acc_zs:0.023715415019762844, acc_full:0.023715415019762844
# --------------------------------------------------------------
# Input:Given Saudi Arabia,
# progress:6/253
# Sub: Saudi Arabia
# Result_ZS:True, ZS Obj: Riyadh.
# , True Obj: Riyadh
# Result_Full:True, Full Obj: Riyadh. R, True Obj: Riyadh
# acc_zs:0.02766798418972332, acc_full:0.02766798418972332
# --------------------------------------------------------------
# Input:Given South Ossetia,
# progress:7/253
# Sub: South Ossetia
# Result_ZS:True, ZS Obj: Tskhinvali., True Obj: Tskhinvali
# Result_Full:True, Full Obj: Tskhinvali., True Obj: Tskhinvali
# acc_zs:0.03162055335968379, acc_full:0.03162055335968379
# --------------------------------------------------------------
# Input:Given Jersey,
# progress:8/253
# Sub: Jersey
# Result_ZS:False, ZS Obj: Newark.
#
# What, True Obj: St. Helier
# Result_Full:False, Full Obj: New Brunswick.
# , True Obj: St. Helier
# acc_zs:0.03162055335968379, acc_full:0.03162055335968379
# --------------------------------------------------------------
# Input:Given El Salvador,
# progress:9/253
# Sub: El Salvador
# Result_ZS:True, ZS Obj: San Salvador.</s></s></s>, True Obj: San Salvador
# Result_Full:True, Full Obj: San Salvador. This city is, True Obj: San Salvador
# acc_zs:0.03557312252964427, acc_full:0.03557312252964427
# --------------------------------------------------------------
# Input:Given Swaziland,
# progress:10/253
# Sub: Swaziland
# Result_ZS:True, ZS Obj: Mbabane.
# , True Obj: Mbabane
# Result_Full:True, Full Obj: Mbabane.</s>, True Obj: Mbabane
# acc_zs:0.039525691699604744, acc_full:0.039525691699604744
# --------------------------------------------------------------
# Input:Given Brunei,
# progress:11/253
# Sub: Brunei
# Result_ZS:True, ZS Obj: Bandar Seri Begaw, True Obj: Bandar Seri Begawan
# Result_Full:True, Full Obj: Bandar Seri Begaw, True Obj: Bandar Seri Begawan
# acc_zs:0.043478260869565216, acc_full:0.043478260869565216
# --------------------------------------------------------------
# Input:Given Namibia,
# progress:12/253
# Sub: Namibia
# Result_ZS:True, ZS Obj: Windhoek.</s></s>, True Obj: Windhoek
# Result_Full:True, Full Obj: Windhoek. Windho, True Obj: Windhoek
# acc_zs:0.04743083003952569, acc_full:0.04743083003952569
# --------------------------------------------------------------
# Input:Given Tunisia,
# progress:13/253
# Sub: Tunisia
# Result_ZS:True, ZS Obj: Tunis. The capital city, True Obj: Tunis
# Result_Full:True, Full Obj: Tunis. This city is, True Obj: Tunis
# acc_zs:0.05138339920948617, acc_full:0.05138339920948617
# --------------------------------------------------------------
# Input:Given South Georgia and the South Sandwich Islands,
# progress:14/253
# Sub: South Georgia and the South Sandwich Islands
# Result_ZS:False, ZS Obj: Stanley.</s></s></s></s>, True Obj: Grytviken
# Result_Full:False, Full Obj: King Edward VII Station. This, True Obj: Grytviken
# acc_zs:0.05138339920948617, acc_full:0.05138339920948617
# --------------------------------------------------------------
# Input:Given Norfolk Island,
# progress:15/253
# Sub: Norfolk Island
# Result_ZS:True, ZS Obj: Kingston.</s></s></s>, True Obj: Kingston
# Result_Full:True, Full Obj: Kingston.</s></s></s>, True Obj: Kingston
# acc_zs:0.05533596837944664, acc_full:0.05533596837944664
# --------------------------------------------------------------
# Input:Given Albania,
# progress:16/253
# Sub: Albania
# Result_ZS:True, ZS Obj: Tirana. What is, True Obj: Tirana
# Result_Full:True, Full Obj: Tirana. Tir, True Obj: Tirana
# acc_zs:0.05928853754940711, acc_full:0.05928853754940711
# --------------------------------------------------------------
# Input:Given Equatorial Guinea,
# progress:17/253
# Sub: Equatorial Guinea
# Result_ZS:True, ZS Obj: Malabo.
#
# , True Obj: Malabo
# Result_Full:True, Full Obj: Malabo. This city, True Obj: Malabo
# acc_zs:0.06324110671936758, acc_full:0.06324110671936758
# --------------------------------------------------------------
# Input:Given Austria,
# progress:18/253
# Sub: Austria
# Result_ZS:True, ZS Obj: Vienna.
#
# Vien, True Obj: Vienna
# Result_Full:True, Full Obj: Vienna. This city is known, True Obj: Vienna
# acc_zs:0.06719367588932806, acc_full:0.06719367588932806
# --------------------------------------------------------------
# Input:Given Sierra Leone,
# progress:19/253
# Sub: Sierra Leone
# Result_ZS:True, ZS Obj: Freetown.</s></s>, True Obj: Freetown
# Result_Full:True, Full Obj: Freetown. This city, True Obj: Freetown
# acc_zs:0.07114624505928854, acc_full:0.07114624505928854
# --------------------------------------------------------------
# Input:Given Guatemala,
# progress:20/253
# Sub: Guatemala
# Result_ZS:True, ZS Obj: Guatemala City.
# , True Obj: Guatemala City
# Result_Full:True, Full Obj: Guatemala City. This, True Obj: Guatemala City
# acc_zs:0.07509881422924901, acc_full:0.07509881422924901
# --------------------------------------------------------------
# Input:Given Mexico,
# progress:21/253
# Sub: Mexico
# Result_ZS:True, ZS Obj: Mexico City.</s></s></s>, True Obj: Mexico City
# Result_Full:True, Full Obj: Mexico City. It is one, True Obj: Mexico City
# acc_zs:0.07905138339920949, acc_full:0.07905138339920949
# --------------------------------------------------------------
# Input:Given Tanzania,
# progress:22/253
# Sub: Tanzania
# Result_ZS:True, ZS Obj: Dodoma.</s></s></s>, True Obj: Dodoma
# Result_Full:True, Full Obj: Dodoma. However, Ar, True Obj: Dodoma
# acc_zs:0.08300395256916997, acc_full:0.08300395256916997
# --------------------------------------------------------------
# Input:Given Sint Maarten,
# progress:23/253
# Sub: Sint Maarten
# Result_ZS:True, ZS Obj: Philipsburg.</s></s>, True Obj: Philipsburg
# Result_Full:True, Full Obj: Philipsburg. This city, True Obj: Philipsburg
# acc_zs:0.08695652173913043, acc_full:0.08695652173913043
# --------------------------------------------------------------
# Input:Given Indonesia,
# progress:24/253
# Sub: Indonesia
# Result_ZS:True, ZS Obj: Jakarta.</s></s></s>, True Obj: Jakarta
# Result_Full:True, Full Obj: Jakarta. Jakarta is, True Obj: Jakarta
# acc_zs:0.09090909090909091, acc_full:0.09090909090909091
# --------------------------------------------------------------
# Input:Given Singapore,
# progress:25/253
# Sub: Singapore
# Result_ZS:True, ZS Obj: Singapore City.</s></s></s>, True Obj: Singapore
# Result_Full:False, Full Obj: a bustling metropolis, True Obj: Singapore
# acc_zs:0.09486166007905138, acc_full:0.09090909090909091
# --------------------------------------------------------------
# Input:Given Cayman Islands,
# progress:26/253
# Sub: Cayman Islands
# Result_ZS:True, ZS Obj: George Town.</s></s></s>, True Obj: George Town
# Result_Full:True, Full Obj: George Town. George Town is, True Obj: George Town
# acc_zs:0.09881422924901186, acc_full:0.09486166007905138
# --------------------------------------------------------------
# Input:Given Malawi,
# progress:27/253
# Sub: Malawi
# Result_ZS:True, ZS Obj: Lilongwe.</s></s>, True Obj: Lilongwe
# Result_Full:True, Full Obj: Lilongwe. Lilong, True Obj: Lilongwe
# acc_zs:0.10276679841897234, acc_full:0.09881422924901186
# --------------------------------------------------------------
# Input:Given Qatar,
# progress:28/253
# Sub: Qatar
# Result_ZS:True, ZS Obj: Doha.
#
# , True Obj: Doha
# Result_Full:True, Full Obj: Doha. Doh, True Obj: Doha
# acc_zs:0.1067193675889328, acc_full:0.10276679841897234
# --------------------------------------------------------------
# Input:Given Spain,
# progress:29/253
# Sub: Spain
# Result_ZS:True, ZS Obj: Madrid.
#
# Madrid, True Obj: Madrid
# Result_Full:True, Full Obj: Madrid. Madrid is a city, True Obj: Madrid
# acc_zs:0.11067193675889328, acc_full:0.1067193675889328
# --------------------------------------------------------------
# Input:Given Serbia,
# progress:30/253
# Sub: Serbia
# Result_ZS:True, ZS Obj: Belgrade. Belgrade is, True Obj: Belgrade
# Result_Full:True, Full Obj: Belgrade. Belgrade is, True Obj: Belgrade
# acc_zs:0.11462450592885376, acc_full:0.11067193675889328
# --------------------------------------------------------------
# Input:Given Italy,
# progress:31/253
# Sub: Italy
# Result_ZS:True, ZS Obj: Rome.
#
# Rome, True Obj: Rome
# Result_Full:True, Full Obj: Rome. However, the capital, True Obj: Rome
# acc_zs:0.11857707509881422, acc_full:0.11462450592885376
# --------------------------------------------------------------
# Input:Given Northern Cyprus,
# progress:32/253
# Sub: Northern Cyprus
# Result_ZS:True, ZS Obj: Nicosia.
#
# , True Obj: Nicosia
# Result_Full:True, Full Obj: Nicosia. This city, True Obj: Nicosia
# acc_zs:0.1225296442687747, acc_full:0.11857707509881422
# --------------------------------------------------------------
# Input:Given Myanmar,
# progress:33/253
# Sub: Myanmar
# Result_ZS:False, ZS Obj: Yangon.</s></s></s>, True Obj: Naypyidaw
# Result_Full:True, Full Obj: Naypyidaw., True Obj: Naypyidaw
# acc_zs:0.1225296442687747, acc_full:0.1225296442687747
# --------------------------------------------------------------
# Input:Given Cyprus,
# progress:34/253
# Sub: Cyprus
# Result_ZS:True, ZS Obj: Nicosia.</s></s>, True Obj: Nicosia
# Result_Full:True, Full Obj: Nicosia. This city, True Obj: Nicosia
# acc_zs:0.12648221343873517, acc_full:0.12648221343873517
# --------------------------------------------------------------
# Input:Given Latvia,
# progress:35/253
# Sub: Latvia
# Result_ZS:True, ZS Obj: Riga.
#
# What, True Obj: Riga
# Result_Full:True, Full Obj: Riga. Riga is, True Obj: Riga
# acc_zs:0.13043478260869565, acc_full:0.13043478260869565
# --------------------------------------------------------------
# Input:Given Pitcairn Islands,
# progress:36/253
# Sub: Pitcairn Islands
# Result_ZS:False, ZS Obj: Stanley. The population of Stanley, True Obj: Adamstown
# Result_Full:False, Full Obj: Stanley.</s></s></s></s>, True Obj: Adamstown
# acc_zs:0.13043478260869565, acc_full:0.13043478260869565
# --------------------------------------------------------------
# Input:Given South Africa,
# progress:37/253
# Sub: South Africa
# Result_ZS:True, ZS Obj: Pretoria.
#
# , True Obj: Pretoria
# Result_Full:True, Full Obj: Pretoria. However,, True Obj: Pretoria
# acc_zs:0.13438735177865613, acc_full:0.13438735177865613
# --------------------------------------------------------------
# Input:Given Trinidad and Tobago,
# progress:38/253
# Sub: Trinidad and Tobago
# Result_ZS:True, ZS Obj: Port of Spain.</s></s>, True Obj: Port of Spain
# Result_Full:True, Full Obj: Port of Spain. Port of, True Obj: Port of Spain
# acc_zs:0.1383399209486166, acc_full:0.1383399209486166
# --------------------------------------------------------------
# Input:Given San Marino,
# progress:39/253
# Sub: San Marino
# Result_ZS:False, ZS Obj: the capital city of San Mar, True Obj: San Marino
# Result_Full:True, Full Obj: San Marino. It is, True Obj: San Marino
# acc_zs:0.1383399209486166, acc_full:0.1422924901185771
# --------------------------------------------------------------
# Input:Given Rwanda,
# progress:40/253
# Sub: Rwanda
# Result_ZS:True, ZS Obj: Kigali.</s></s>, True Obj: Kigali
# Result_Full:True, Full Obj: Kigali. Kig, True Obj: Kigali
# acc_zs:0.1422924901185771, acc_full:0.14624505928853754
# --------------------------------------------------------------
# Input:Given French Guiana,
# progress:41/253
# Sub: French Guiana
# Result_ZS:False, ZS Obj: Paris.
# Answer:, True Obj: Cayenne
# Result_Full:True, Full Obj: Cayenne. Cay, True Obj: Cayenne
# acc_zs:0.1422924901185771, acc_full:0.15019762845849802
# --------------------------------------------------------------
# Input:Given Nigeria,
# progress:42/253
# Sub: Nigeria
# Result_ZS:True, ZS Obj: Abuja.
#
# What, True Obj: Abuja
# Result_Full:True, Full Obj: Abuja. Abuja is, True Obj: Abuja
# acc_zs:0.14624505928853754, acc_full:0.1541501976284585
# --------------------------------------------------------------
# Input:Given Gambia,
# progress:43/253
# Sub: Gambia
# Result_ZS:True, ZS Obj: Banjul.</s></s>, True Obj: Banjul
# Result_Full:True, Full Obj: Banjul. Banj, True Obj: Banjul
# acc_zs:0.15019762845849802, acc_full:0.15810276679841898
# --------------------------------------------------------------
# Input:Given Egypt,
# progress:44/253
# Sub: Egypt
# Result_ZS:True, ZS Obj: Cairo.</s></s></s>, True Obj: Cairo
# Result_Full:True, Full Obj: Cairo. Cairo is, True Obj: Cairo
# acc_zs:0.1541501976284585, acc_full:0.16205533596837945
# --------------------------------------------------------------
# Input:Given United States,
# progress:45/253
# Sub: United States
# Result_ZS:True, ZS Obj: Washington, D.C., True Obj: Washington, D.C.
# Result_Full:True, Full Obj: Washington, D.C., True Obj: Washington, D.C.
# acc_zs:0.15810276679841898, acc_full:0.16600790513833993
# --------------------------------------------------------------
# Input:Given Mexico,
# progress:46/253
# Sub: Mexico
# Result_ZS:True, ZS Obj: Mexico City.</s></s></s>, True Obj: Mexico City
# Result_Full:True, Full Obj: Mexico City. It is one, True Obj: Mexico City
# acc_zs:0.16205533596837945, acc_full:0.16996047430830039
# --------------------------------------------------------------
# Input:Given Comoros,
# progress:47/253
# Sub: Comoros
# Result_ZS:True, ZS Obj: Moroni.</s></s></s>, True Obj: Moroni
# Result_Full:True, Full Obj: Moroni.</s></s></s>, True Obj: Moroni
# acc_zs:0.16600790513833993, acc_full:0.17391304347826086
# --------------------------------------------------------------
# Input:Given Zambia,
# progress:48/253
# Sub: Zambia
# Result_ZS:True, ZS Obj: Lusaka.</s></s>, True Obj: Lusaka
# Result_Full:True, Full Obj: Lusaka. Lus, True Obj: Lusaka
# acc_zs:0.16996047430830039, acc_full:0.17786561264822134
# --------------------------------------------------------------
# Input:Given Saudi Arabia,
# progress:49/253
# Sub: Saudi Arabia
# Result_ZS:True, ZS Obj: Riyadh.
# , True Obj: Riyadh
# Result_Full:True, Full Obj: Riyadh. R, True Obj: Riyadh
# acc_zs:0.17391304347826086, acc_full:0.18181818181818182
# --------------------------------------------------------------
# Input:Given Senegal,
# progress:50/253
# Sub: Senegal
# Result_ZS:True, ZS Obj: Dakar.</s></s></s>, True Obj: Dakar
# Result_Full:True, Full Obj: Dakar. The official language, True Obj: Dakar
# acc_zs:0.17786561264822134, acc_full:0.1857707509881423
# --------------------------------------------------------------
# Input:Given Russia,
# progress:51/253
# Sub: Russia
# Result_ZS:True, ZS Obj: Moscow.</s></s></s></s>, True Obj: Moscow
# Result_Full:True, Full Obj: Moscow. Moscow is the largest, True Obj: Moscow
# acc_zs:0.18181818181818182, acc_full:0.18972332015810275
# --------------------------------------------------------------
# Input:Given Algeria,
# progress:52/253
# Sub: Algeria
# Result_ZS:True, ZS Obj: Algiers.</s></s>, True Obj: Algiers
# Result_Full:True, Full Obj: Algiers. Alg, True Obj: Algiers
# acc_zs:0.1857707509881423, acc_full:0.19367588932806323
# --------------------------------------------------------------
# Input:Given Bermuda,
# progress:53/253
# Sub: Bermuda
# Result_ZS:True, ZS Obj: Hamilton.</s></s></s></s>, True Obj: Hamilton
# Result_Full:True, Full Obj: Hamilton. Hamilton is the largest, True Obj: Hamilton
# acc_zs:0.18972332015810275, acc_full:0.1976284584980237
# --------------------------------------------------------------
# Input:Given Zimbabwe,
# progress:54/253
# Sub: Zimbabwe
# Result_ZS:True, ZS Obj: Harare.</s></s></s>, True Obj: Harare
# Result_Full:True, Full Obj: Harare. Harare is, True Obj: Harare
# acc_zs:0.19367588932806323, acc_full:0.2015810276679842
# --------------------------------------------------------------
# Input:Given India,
# progress:55/253
# Sub: India
# Result_ZS:True, ZS Obj: New Delhi.
#
# What, True Obj: New Delhi
# Result_Full:True, Full Obj: New Delhi. However, there, True Obj: New Delhi
# acc_zs:0.1976284584980237, acc_full:0.20553359683794467
# --------------------------------------------------------------
# Input:Given Guernsey,
# progress:56/253
# Sub: Guernsey
# Result_ZS:True, ZS Obj: St Peter Port.</s></s>, True Obj: St. Peter Port
# Result_Full:True, Full Obj: St. Peter Port. It, True Obj: St. Peter Port
# acc_zs:0.2015810276679842, acc_full:0.20948616600790515
# --------------------------------------------------------------
# Input:Given Colombia,
# progress:57/253
# Sub: Colombia
# Result_ZS:True, ZS Obj: Bogotá.</s></s>, True Obj: Bogot
# Result_Full:True, Full Obj: Bogotá. This city, True Obj: Bogot
# acc_zs:0.20553359683794467, acc_full:0.2134387351778656
# --------------------------------------------------------------
# Input:Given Saint Martin,
# progress:58/253
# Sub: Saint Martin
# Result_ZS:False, ZS Obj: Paris.
#
# What is, True Obj: Marigot
# Result_Full:False, Full Obj: Saint Martin. The official language, True Obj: Marigot
# acc_zs:0.20553359683794467, acc_full:0.2134387351778656
# --------------------------------------------------------------
# Input:Given Nepal,
# progress:59/253
# Sub: Nepal
# Result_ZS:True, ZS Obj: Kathmandu. What is, True Obj: Kathmandu
# Result_Full:True, Full Obj: Kathmandu. Kathmand, True Obj: Kathmandu
# acc_zs:0.20948616600790515, acc_full:0.21739130434782608
# --------------------------------------------------------------
# Input:Given Macedonia,
# progress:60/253
# Sub: Macedonia
# Result_ZS:True, ZS Obj: Skopje.</s></s>, True Obj: Skopje
# Result_Full:True, Full Obj: Skopje. This city, True Obj: Skopje
# acc_zs:0.2134387351778656, acc_full:0.22134387351778656
# --------------------------------------------------------------
# Input:Given Grenada,
# progress:61/253
# Sub: Grenada
# Result_ZS:True, ZS Obj: St. George's., True Obj: St. George's
# Result_Full:True, Full Obj: St. George's., True Obj: St. George's
# acc_zs:0.21739130434782608, acc_full:0.22529644268774704
# --------------------------------------------------------------
# Input:Given Samoa,
# progress:62/253
# Sub: Samoa
# Result_ZS:True, ZS Obj: Apia.</s></s></s>, True Obj: Apia
# Result_Full:True, Full Obj: Apia.</s></s></s>, True Obj: Apia
# acc_zs:0.22134387351778656, acc_full:0.22924901185770752
# --------------------------------------------------------------
# Input:Given Malta,
# progress:63/253
# Sub: Malta
# Result_ZS:True, ZS Obj: Valletta.
#
# , True Obj: Valletta
# Result_Full:True, Full Obj: Valletta. It is, True Obj: Valletta
# acc_zs:0.22529644268774704, acc_full:0.233201581027668
# --------------------------------------------------------------
# Input:Given Afghanistan,
# progress:64/253
# Sub: Afghanistan
# Result_ZS:True, ZS Obj: Kabul.</s></s></s>, True Obj: Kabul
# Result_Full:True, Full Obj: Kabul. Kabul is, True Obj: Kabul
# acc_zs:0.22924901185770752, acc_full:0.23715415019762845
# --------------------------------------------------------------
# Input:Given Australia,
# progress:65/253
# Sub: Australia
# Result_ZS:True, ZS Obj: Canberra.
#
# , True Obj: Canberra
# Result_Full:True, Full Obj: Canberra. Canber, True Obj: Canberra
# acc_zs:0.233201581027668, acc_full:0.24110671936758893
# --------------------------------------------------------------
# Input:Given Ghana,
# progress:66/253
# Sub: Ghana
# Result_ZS:True, ZS Obj: Accra.</s></s></s>, True Obj: Accra
# Result_Full:True, Full Obj: Accra. Accra is, True Obj: Accra
# acc_zs:0.23715415019762845, acc_full:0.2450592885375494
# --------------------------------------------------------------
# Input:Given Solomon Islands,
# progress:67/253
# Sub: Solomon Islands
# Result_ZS:True, ZS Obj: Honiara.</s></s>, True Obj: Honiara
# Result_Full:True, Full Obj: Honiara. This city, True Obj: Honiara
# acc_zs:0.24110671936758893, acc_full:0.2490118577075099
# --------------------------------------------------------------
# Input:Given Cocos (Keeling) Islands,
# progress:68/253
# Sub: Cocos (Keeling) Islands
# Result_ZS:False, ZS Obj: Brisbane.
# , True Obj: West Island
# Result_Full:False, Full Obj: Cocos Town. The, True Obj: West Island
# acc_zs:0.24110671936758893, acc_full:0.2490118577075099
# --------------------------------------------------------------
# Input:Given Liechtenstein,
# progress:69/253
# Sub: Liechtenstein
# Result_ZS:True, ZS Obj: Vaduz.</s></s>, True Obj: Vaduz
# Result_Full:True, Full Obj: Vaduz. It is, True Obj: Vaduz
# acc_zs:0.2450592885375494, acc_full:0.25296442687747034
# --------------------------------------------------------------
# Input:Given Nigeria,
# progress:70/253
# Sub: Nigeria
# Result_ZS:True, ZS Obj: Abuja.
#
# What, True Obj: Abuja
# Result_Full:True, Full Obj: Abuja. Abuja is, True Obj: Abuja
# acc_zs:0.2490118577075099, acc_full:0.25691699604743085
# --------------------------------------------------------------
# Input:Given Croatia,
# progress:71/253
# Sub: Croatia
# Result_ZS:True, ZS Obj: Zagreb.</s></s></s>, True Obj: Zagreb
# Result_Full:True, Full Obj: Zagreb. This city is, True Obj: Zagreb
# acc_zs:0.25296442687747034, acc_full:0.2608695652173913
# --------------------------------------------------------------
# Input:Given Saint Kitts and Nevis,
# progress:72/253
# Sub: Saint Kitts and Nevis
# Result_ZS:True, ZS Obj: Basseterre.</s></s>, True Obj: Basseterre
# Result_Full:True, Full Obj: Basseterre. This city, True Obj: Basseterre
# acc_zs:0.25691699604743085, acc_full:0.2648221343873518
# --------------------------------------------------------------
# Input:Given Malaysia,
# progress:73/253
# Sub: Malaysia
# Result_ZS:True, ZS Obj: Kuala Lumpur, True Obj: Kuala Lumpur
# Result_Full:True, Full Obj: Kuala Lumpur, True Obj: Kuala Lumpur
# acc_zs:0.2608695652173913, acc_full:0.26877470355731226
# --------------------------------------------------------------
# Input:Given Morocco,
# progress:74/253
# Sub: Morocco
# Result_ZS:True, ZS Obj: Rabat. What is the, True Obj: Rabat
# Result_Full:True, Full Obj: Rabat. This city is, True Obj: Rabat
# acc_zs:0.2648221343873518, acc_full:0.2727272727272727
# --------------------------------------------------------------
# Input:Given Belize,
# progress:75/253
# Sub: Belize
# Result_ZS:True, ZS Obj: Belmopan.</s>, True Obj: Belmopan
# Result_Full:True, Full Obj: Belmopan. Bel, True Obj: Belmopan
# acc_zs:0.26877470355731226, acc_full:0.2766798418972332
# --------------------------------------------------------------
# Input:Given Wallis and Futuna,
# progress:76/253
# Sub: Wallis and Futuna
# Result_ZS:False, ZS Obj: Nouméa. What, True Obj: Mata-Utu
# Result_Full:True, Full Obj: Mata-Utu., True Obj: Mata-Utu
# acc_zs:0.26877470355731226, acc_full:0.28063241106719367
# --------------------------------------------------------------
# Input:Given Gabon,
# progress:77/253
# Sub: Gabon
# Result_ZS:True, ZS Obj: Libreville.
#
# , True Obj: Libreville
# Result_Full:True, Full Obj: Libreville. This city, True Obj: Libreville
# acc_zs:0.2727272727272727, acc_full:0.2845849802371542
# --------------------------------------------------------------
# Input:Given Niger,
# progress:78/253
# Sub: Niger
# Result_ZS:False, ZS Obj: Abuja.
#
# What, True Obj: Niamey
# Result_Full:True, Full Obj: Niamey. Niame, True Obj: Niamey
# acc_zs:0.2727272727272727, acc_full:0.2885375494071146
# --------------------------------------------------------------
# Input:Given Kiribati,
# progress:79/253
# Sub: Kiribati
# Result_ZS:True, ZS Obj: Tarawa.</s></s></s>, True Obj: Tarawa
# Result_Full:True, Full Obj: Tarawa.</s></s></s>, True Obj: Tarawa
# acc_zs:0.2766798418972332, acc_full:0.2924901185770751
# --------------------------------------------------------------
# Input:Given Denmark,
# progress:80/253
# Sub: Denmark
# Result_ZS:True, ZS Obj: Copenhagen.</s>, True Obj: Copenhagen
# Result_Full:True, Full Obj: Copenhagen. C, True Obj: Copenhagen
# acc_zs:0.28063241106719367, acc_full:0.2964426877470356
# --------------------------------------------------------------
# Input:Given Isle of Man,
# progress:81/253
# Sub: Isle of Man
# Result_ZS:True, ZS Obj: Douglas.</s></s></s></s>, True Obj: Douglas
# Result_Full:True, Full Obj: Douglas.</s></s></s></s>, True Obj: Douglas
# acc_zs:0.2845849802371542, acc_full:0.30039525691699603
# --------------------------------------------------------------
# Input:Given Lebanon,
# progress:82/253
# Sub: Lebanon
# Result_ZS:True, ZS Obj: Beirut.
#
# , True Obj: Beirut
# Result_Full:True, Full Obj: Beirut. Beir, True Obj: Beirut
# acc_zs:0.2885375494071146, acc_full:0.30434782608695654
# --------------------------------------------------------------
# Input:Given Slovenia,
# progress:83/253
# Sub: Slovenia
# Result_ZS:True, ZS Obj: Ljubljana., True Obj: Ljubljana
# Result_Full:True, Full Obj: Ljubljana., True Obj: Ljubljana
# acc_zs:0.2924901185770751, acc_full:0.308300395256917
# --------------------------------------------------------------
# Input:Given Norway,
# progress:84/253
# Sub: Norway
# Result_ZS:True, ZS Obj: Oslo.</s></s></s>, True Obj: Oslo
# Result_Full:True, Full Obj: Oslo.</s></s></s>, True Obj: Oslo
# acc_zs:0.2964426877470356, acc_full:0.31225296442687744
# --------------------------------------------------------------
# Input:Given Easter Island,
# progress:85/253
# Sub: Easter Island
# Result_ZS:False, ZS Obj: Santiago, which is the capital, True Obj: Hanga Roa
# Result_Full:False, Full Obj: Santiago. The official language is, True Obj: Hanga Roa
# acc_zs:0.2964426877470356, acc_full:0.31225296442687744
# --------------------------------------------------------------
# Input:Given Nicaragua,
# progress:86/253
# Sub: Nicaragua
# Result_ZS:True, ZS Obj: Managua.</s></s>, True Obj: Managua
# Result_Full:True, Full Obj: Managua. This city, True Obj: Managua
# acc_zs:0.30039525691699603, acc_full:0.31620553359683795
# --------------------------------------------------------------
# Input:Given Mauritania,
# progress:87/253
# Sub: Mauritania
# Result_ZS:True, ZS Obj: Nouakchott.</s>, True Obj: Nouakchott
# Result_Full:True, Full Obj: Nouakchott. This, True Obj: Nouakchott
# acc_zs:0.30434782608695654, acc_full:0.3201581027667984
# --------------------------------------------------------------
# Input:Given Djibouti,
# progress:88/253
# Sub: Djibouti
# Result_ZS:True, ZS Obj: Djibouti City, True Obj: Djibouti
# Result_Full:True, Full Obj: Djibouti., True Obj: Djibouti
# acc_zs:0.308300395256917, acc_full:0.3241106719367589
# --------------------------------------------------------------
# Input:Given Mali,
# progress:89/253
# Sub: Mali
# Result_ZS:True, ZS Obj: Bamako.</s></s>, True Obj: Bamako
# Result_Full:True, Full Obj: Bamako.</s></s>, True Obj: Bamako
# acc_zs:0.31225296442687744, acc_full:0.32806324110671936
# --------------------------------------------------------------
# Input:Given China,
# progress:90/253
# Sub: China
# Result_ZS:True, ZS Obj: Beijing.</s></s></s></s>, True Obj: Beijing
# Result_Full:True, Full Obj: Beijing. Beijing is a city, True Obj: Beijing
# acc_zs:0.31620553359683795, acc_full:0.33201581027667987
# --------------------------------------------------------------
# Input:Given Puerto Rico,
# progress:91/253
# Sub: Puerto Rico
# Result_ZS:True, ZS Obj: San Juan.
#
# San, True Obj: San Juan
# Result_Full:True, Full Obj: San Juan. This city is, True Obj: San Juan
# acc_zs:0.3201581027667984, acc_full:0.3359683794466403
# --------------------------------------------------------------
# Input:Given Montenegro,
# progress:92/253
# Sub: Montenegro
# Result_ZS:True, ZS Obj: Podgorica.</s></s>, True Obj: Podgorica
# Result_Full:True, Full Obj: Podgorica. It is, True Obj: Podgorica
# acc_zs:0.3241106719367589, acc_full:0.33992094861660077
# --------------------------------------------------------------
# Input:Given Abkhazia,
# progress:93/253
# Sub: Abkhazia
# Result_ZS:False, ZS Obj: Tbilisi.
#
# , True Obj: Sukhumi
# Result_Full:True, Full Obj: Sukhumi.</s></s>, True Obj: Sukhumi
# acc_zs:0.3241106719367589, acc_full:0.3438735177865613
# --------------------------------------------------------------
# Input:Given Kuwait,
# progress:94/253
# Sub: Kuwait
# Result_ZS:True, ZS Obj: Kuwait City.</s></s>, True Obj: Kuwait City
# Result_Full:True, Full Obj: Kuwait City. It is, True Obj: Kuwait City
# acc_zs:0.32806324110671936, acc_full:0.34782608695652173
# --------------------------------------------------------------
# Input:Given Madagascar,
# progress:95/253
# Sub: Madagascar
# Result_ZS:True, ZS Obj: Antananarivo., True Obj: Antananarivo
# Result_Full:True, Full Obj: Antananarivo., True Obj: Antananarivo
# acc_zs:0.33201581027667987, acc_full:0.35177865612648224
# --------------------------------------------------------------
# Input:Given Romania,
# progress:96/253
# Sub: Romania
# Result_ZS:True, ZS Obj: Bucharest.</s></s></s>, True Obj: Bucharest
# Result_Full:True, Full Obj: Bucharest. This city is, True Obj: Bucharest
# acc_zs:0.3359683794466403, acc_full:0.3557312252964427
# --------------------------------------------------------------
# Input:Given Mozambique,
# progress:97/253
# Sub: Mozambique
# Result_ZS:True, ZS Obj: Maputo.</s></s></s>, True Obj: Maputo
# Result_Full:True, Full Obj: Maputo. Maputo is, True Obj: Maputo
# acc_zs:0.33992094861660077, acc_full:0.35968379446640314
# --------------------------------------------------------------
# Input:Given United Kingdom Northern Ireland,
# progress:98/253
# Sub: United Kingdom Northern Ireland
# Result_ZS:True, ZS Obj: Belfast.</s></s>, True Obj: Belfast
# Result_Full:True, Full Obj: Belfast. This city, True Obj: Belfast
# acc_zs:0.3438735177865613, acc_full:0.36363636363636365
# --------------------------------------------------------------
# Input:Given Eritrea,
# progress:99/253
# Sub: Eritrea
# Result_ZS:True, ZS Obj: Asmara.</s></s>, True Obj: Asmara
# Result_Full:True, Full Obj: Asmara. Asm, True Obj: Asmara
# acc_zs:0.34782608695652173, acc_full:0.3675889328063241
# --------------------------------------------------------------
# Input:Given Somalia,
# progress:100/253
# Sub: Somalia
# Result_ZS:True, ZS Obj: Mogadishu., True Obj: Mogadishu
# Result_Full:True, Full Obj: Mogadishu., True Obj: Mogadishu
# acc_zs:0.35177865612648224, acc_full:0.3715415019762846
# --------------------------------------------------------------
# Input:Given Turkey,
# progress:101/253
# Sub: Turkey
# Result_ZS:True, ZS Obj: Ankara.</s></s>, True Obj: Ankara
# Result_Full:True, Full Obj: Ankara. Ank, True Obj: Ankara
# acc_zs:0.3557312252964427, acc_full:0.37549407114624506
# --------------------------------------------------------------
# Input:Given Portugal,
# progress:102/253
# Sub: Portugal
# Result_ZS:True, ZS Obj: Lisbon.
#
# L, True Obj: Lisbon
# Result_Full:True, Full Obj: Lisbon. It is a, True Obj: Lisbon
# acc_zs:0.35968379446640314, acc_full:0.3794466403162055
# --------------------------------------------------------------
# Input:Given Ireland,
# progress:103/253
# Sub: Ireland
# Result_ZS:True, ZS Obj: Dublin.</s></s></s></s>, True Obj: Dublin
# Result_Full:True, Full Obj: Dublin. Dublin is a city, True Obj: Dublin
# acc_zs:0.36363636363636365, acc_full:0.383399209486166
# --------------------------------------------------------------
# Input:Given Saint Vincent and the Grenadines,
# progress:104/253
# Sub: Saint Vincent and the Grenadines
# Result_ZS:True, ZS Obj: Kingstown.</s></s>, True Obj: Kingstown
# Result_Full:True, Full Obj: Kingstown. This city, True Obj: Kingstown
# acc_zs:0.3675889328063241, acc_full:0.38735177865612647
# --------------------------------------------------------------
# Input:Given Sudan,
# progress:105/253
# Sub: Sudan
# Result_ZS:True, ZS Obj: Khartoum.</s>, True Obj: Khartoum
# Result_Full:True, Full Obj: Khartoum.</s>, True Obj: Khartoum
# acc_zs:0.3715415019762846, acc_full:0.391304347826087
# --------------------------------------------------------------
# Input:Given Chile,
# progress:106/253
# Sub: Chile
# Result_ZS:True, ZS Obj: Santiago.</s></s></s></s>, True Obj: Santiago
# Result_Full:True, Full Obj: Santiago. This city is located, True Obj: Santiago
# acc_zs:0.37549407114624506, acc_full:0.3952569169960474
# --------------------------------------------------------------
# Input:Given Falkland Islands,
# progress:107/253
# Sub: Falkland Islands
# Result_ZS:True, ZS Obj: Stanley.</s></s></s></s>, True Obj: Stanley
# Result_Full:True, Full Obj: Stanley.</s></s></s></s>, True Obj: Stanley
# acc_zs:0.3794466403162055, acc_full:0.39920948616600793
# --------------------------------------------------------------
# Input:Given Christmas Island,
# progress:108/253
# Sub: Christmas Island
# Result_ZS:False, ZS Obj: Canberra.
#
# , True Obj: Flying Fish Cove
# Result_Full:False, Full Obj: Brisbane. This, True Obj: Flying Fish Cove
# acc_zs:0.3794466403162055, acc_full:0.39920948616600793
# --------------------------------------------------------------
# Input:Given Oman,
# progress:109/253
# Sub: Oman
# Result_ZS:True, ZS Obj: Muscat.</s></s></s>, True Obj: Muscat
# Result_Full:True, Full Obj: Muscat. Muscat is, True Obj: Muscat
# acc_zs:0.383399209486166, acc_full:0.4031620553359684
# --------------------------------------------------------------
# Input:Given France,
# progress:110/253
# Sub: France
# Result_ZS:True, ZS Obj: Paris.
#
# Given, True Obj: Paris
# Result_Full:True, Full Obj: Paris. Paris is known as, True Obj: Paris
# acc_zs:0.38735177865612647, acc_full:0.40711462450592883
# --------------------------------------------------------------
# Input:Given Japan,
# progress:111/253
# Sub: Japan
# Result_ZS:True, ZS Obj: Tokyo.</s></s></s></s>, True Obj: Tokyo
# Result_Full:True, Full Obj: Tokyo. Tokyo is a bust, True Obj: Tokyo
# acc_zs:0.391304347826087, acc_full:0.41106719367588934
# --------------------------------------------------------------
# Input:Given Philippines,
# progress:112/253
# Sub: Philippines
# Result_ZS:True, ZS Obj: Manila.
#
# Man, True Obj: Manila
# Result_Full:True, Full Obj: Manila. Manila is, True Obj: Manila
# acc_zs:0.3952569169960474, acc_full:0.4150197628458498
# --------------------------------------------------------------
# Input:Given Kazakhstan,
# progress:113/253
# Sub: Kazakhstan
# Result_ZS:True, ZS Obj: Astana.</s></s></s>, True Obj: Astana
# Result_Full:True, Full Obj: Astana. Astana is, True Obj: Astana
# acc_zs:0.39920948616600793, acc_full:0.4189723320158103
# --------------------------------------------------------------
# Input:Given United Arab Emirates,
# progress:114/253
# Sub: United Arab Emirates
# Result_ZS:True, ZS Obj: Abu Dhabi.
# , True Obj: Abu Dhabi
# Result_Full:True, Full Obj: Abu Dhabi. This, True Obj: Abu Dhabi
# acc_zs:0.4031620553359684, acc_full:0.42292490118577075
# --------------------------------------------------------------
# Input:Given Poland,
# progress:115/253
# Sub: Poland
# Result_ZS:True, ZS Obj: Warsaw.</s></s></s>, True Obj: Warsaw
# Result_Full:True, Full Obj: Warsaw. It is the, True Obj: Warsaw
# acc_zs:0.40711462450592883, acc_full:0.4268774703557312
# --------------------------------------------------------------
# Input:Given Somaliland,
# progress:116/253
# Sub: Somaliland
# Result_ZS:False, ZS Obj: Mogadishu., True Obj: Hargeisa
# Result_Full:True, Full Obj: Hargeisa. This city, True Obj: Hargeisa
# acc_zs:0.40711462450592883, acc_full:0.4308300395256917
# --------------------------------------------------------------
# Input:Given Honduras,
# progress:117/253
# Sub: Honduras
# Result_ZS:True, ZS Obj: Tegucigalpa, True Obj: Tegucigalpa
# Result_Full:True, Full Obj: Tegucigalpa, True Obj: Tegucigalpa
# acc_zs:0.41106719367588934, acc_full:0.43478260869565216
# --------------------------------------------------------------
# Input:Given Ukraine,
# progress:118/253
# Sub: Ukraine
# Result_ZS:True, ZS Obj: Kiev.</s></s></s>, True Obj: Kiev
# Result_Full:True, Full Obj: Kiev. Kiev is, True Obj: Kiev
# acc_zs:0.4150197628458498, acc_full:0.43873517786561267
# --------------------------------------------------------------
# Input:Given Liberia,
# progress:119/253
# Sub: Liberia
# Result_ZS:True, ZS Obj: Monrovia.</s></s>, True Obj: Monrovia
# Result_Full:True, Full Obj: Monrovia. This city, True Obj: Monrovia
# acc_zs:0.4189723320158103, acc_full:0.4426877470355731
# --------------------------------------------------------------
# Input:Given Tajikistan,
# progress:120/253
# Sub: Tajikistan
# Result_ZS:True, ZS Obj: Dushanbe. What, True Obj: Dushanbe
# Result_Full:True, Full Obj: Dushanbe. This, True Obj: Dushanbe
# acc_zs:0.42292490118577075, acc_full:0.44664031620553357
# --------------------------------------------------------------
# Input:Given Fiji,
# progress:121/253
# Sub: Fiji
# Result_ZS:True, ZS Obj: Suva.</s></s></s>, True Obj: Suva
# Result_Full:True, Full Obj: Suva.</s></s></s>, True Obj: Suva
# acc_zs:0.4268774703557312, acc_full:0.4505928853754941
# --------------------------------------------------------------
# Input:Given Lesotho,
# progress:122/253
# Sub: Lesotho
# Result_ZS:True, ZS Obj: Maseru.</s></s>, True Obj: Maseru
# Result_Full:True, Full Obj: Maseru. Maser, True Obj: Maseru
# acc_zs:0.4308300395256917, acc_full:0.45454545454545453
# --------------------------------------------------------------
# Input:Given Germany,
# progress:123/253
# Sub: Germany
# Result_ZS:True, ZS Obj: Berlin.</s></s></s></s>, True Obj: Berlin
# Result_Full:True, Full Obj: Berlin. Berlin is a city, True Obj: Berlin
# acc_zs:0.43478260869565216, acc_full:0.45849802371541504
# --------------------------------------------------------------
# Input:Given Lithuania,
# progress:124/253
# Sub: Lithuania
# Result_ZS:True, ZS Obj: Vilnius.</s></s>, True Obj: Vilnius
# Result_Full:True, Full Obj: Vilnius. This city, True Obj: Vilnius
# acc_zs:0.43873517786561267, acc_full:0.4624505928853755
# --------------------------------------------------------------
# Input:Given Palestine,
# progress:125/253
# Sub: Palestine
# Result_ZS:True, ZS Obj: Jerusalem.
#
# Jer, True Obj: Jerusalem
# Result_Full:True, Full Obj: Jerusalem. The official language is, True Obj: Jerusalem
# acc_zs:0.4426877470355731, acc_full:0.466403162055336
# --------------------------------------------------------------
# Input:Given Kyrgyzstan,
# progress:126/253
# Sub: Kyrgyzstan
# Result_ZS:True, ZS Obj: Bishkek.</s>, True Obj: Bishkek
# Result_Full:True, Full Obj: Bishkek. This, True Obj: Bishkek
# acc_zs:0.44664031620553357, acc_full:0.47035573122529645
# --------------------------------------------------------------
# Input:Given British Virgin Islands,
# progress:127/253
# Sub: British Virgin Islands
# Result_ZS:False, ZS Obj: Kingstown.</s></s>, True Obj: Road Town
# Result_Full:True, Full Obj: Road Town.</s></s></s>, True Obj: Road Town
# acc_zs:0.44664031620553357, acc_full:0.4743083003952569
# --------------------------------------------------------------
# Input:Given Italy,
# progress:128/253
# Sub: Italy
# Result_ZS:True, ZS Obj: Rome.
#
# Rome, True Obj: Rome
# Result_Full:True, Full Obj: Rome. However, the capital, True Obj: Rome
# acc_zs:0.4505928853754941, acc_full:0.4782608695652174
# --------------------------------------------------------------
# Input:Given Belarus,
# progress:129/253
# Sub: Belarus
# Result_ZS:True, ZS Obj: Minsk.</s></s>, True Obj: Minsk
# Result_Full:True, Full Obj: Minsk. This city, True Obj: Minsk
# acc_zs:0.45454545454545453, acc_full:0.48221343873517786
# --------------------------------------------------------------
# Input:Given Laos,
# progress:130/253
# Sub: Laos
# Result_ZS:True, ZS Obj: Vientiane. What is, True Obj: Vientiane
# Result_Full:True, Full Obj: Vientiane. It is, True Obj: Vientiane
# acc_zs:0.45849802371541504, acc_full:0.48616600790513836
# --------------------------------------------------------------
# Input:Given Uganda,
# progress:131/253
# Sub: Uganda
# Result_ZS:True, ZS Obj: Kampala.</s></s></s>, True Obj: Kampala
# Result_Full:True, Full Obj: Kampala. Kampala is, True Obj: Kampala
# acc_zs:0.4624505928853755, acc_full:0.4901185770750988
# --------------------------------------------------------------
# Input:Given Cape Verde,
# progress:132/253
# Sub: Cape Verde
# Result_ZS:True, ZS Obj: Praia.</s></s></s>, True Obj: Praia
# Result_Full:True, Full Obj: Praia. Praia is, True Obj: Praia
# acc_zs:0.466403162055336, acc_full:0.49407114624505927
# --------------------------------------------------------------
# Input:Given North Korea,
# progress:133/253
# Sub: North Korea
# Result_ZS:True, ZS Obj: Pyongyang.
# , True Obj: Pyongyang
# Result_Full:True, Full Obj: Pyongyang. This, True Obj: Pyongyang
# acc_zs:0.47035573122529645, acc_full:0.4980237154150198
# --------------------------------------------------------------
# Input:Given Saint Lucia,
# progress:134/253
# Sub: Saint Lucia
# Result_ZS:True, ZS Obj: Castries.</s></s></s>, True Obj: Castries
# Result_Full:False, Full Obj: Soufriere. This city, True Obj: Castries
# acc_zs:0.4743083003952569, acc_full:0.4980237154150198
# --------------------------------------------------------------
# Input:Given Argentina,
# progress:135/253
# Sub: Argentina
# Result_ZS:True, ZS Obj: Buenos Aires.</s></s></s>, True Obj: Buenos Aires
# Result_Full:True, Full Obj: Buenos Aires. This city is, True Obj: Buenos Aires
# acc_zs:0.4782608695652174, acc_full:0.5019762845849802
# --------------------------------------------------------------
# Input:Given Peru,
# progress:136/253
# Sub: Peru
# Result_ZS:True, ZS Obj: Lima.
#
# What, True Obj: Lima
# Result_Full:True, Full Obj: Lima. Lima is, True Obj: Lima
# acc_zs:0.48221343873517786, acc_full:0.5059288537549407
# --------------------------------------------------------------
# Input:Given Andorra,
# progress:137/253
# Sub: Andorra
# Result_ZS:True, ZS Obj: Andorra la Vella, True Obj: Andorra la Vella
# Result_Full:True, Full Obj: Andorra la Vella, True Obj: Andorra la Vella
# acc_zs:0.48616600790513836, acc_full:0.5098814229249012
# --------------------------------------------------------------
# Input:Given Libya,
# progress:138/253
# Sub: Libya
# Result_ZS:True, ZS Obj: Tripoli.</s></s>, True Obj: Tripoli
# Result_Full:True, Full Obj: Tripoli. This city, True Obj: Tripoli
# acc_zs:0.4901185770750988, acc_full:0.5138339920948617
# --------------------------------------------------------------
# Input:Given Turks and Caicos Islands,
# progress:139/253
# Sub: Turks and Caicos Islands
# Result_ZS:False, ZS Obj: Providenciales.</s>, True Obj: Cockburn Town
# Result_Full:True, Full Obj: Cockburn Town. This, True Obj: Cockburn Town
# acc_zs:0.4901185770750988, acc_full:0.5177865612648221
# --------------------------------------------------------------
# Input:Given Antigua and Barbuda,
# progress:140/253
# Sub: Antigua and Barbuda
# Result_ZS:True, ZS Obj: St. John’s., True Obj: St. John's
# Result_Full:True, Full Obj: St. John’s., True Obj: St. John's
# acc_zs:0.49407114624505927, acc_full:0.5217391304347826
# --------------------------------------------------------------
# Input:Given French Polynesia,
# progress:141/253
# Sub: French Polynesia
# Result_ZS:True, ZS Obj: Pape'ete.
# , True Obj: Papeete
# Result_Full:True, Full Obj: Pape'ete. This, True Obj: Papeete
# acc_zs:0.4980237154150198, acc_full:0.525691699604743
# --------------------------------------------------------------
# Input:Given India,
# progress:142/253
# Sub: India
# Result_ZS:True, ZS Obj: New Delhi.
#
# What, True Obj: New Delhi
# Result_Full:True, Full Obj: New Delhi. However, there, True Obj: New Delhi
# acc_zs:0.5019762845849802, acc_full:0.5296442687747036
# --------------------------------------------------------------
# Input:Given Czech Republic,
# progress:143/253
# Sub: Czech Republic
# Result_ZS:True, ZS Obj: Prague.</s></s></s>, True Obj: Prague
# Result_Full:True, Full Obj: Prague. Prague is, True Obj: Prague
# acc_zs:0.5059288537549407, acc_full:0.5335968379446641
# --------------------------------------------------------------
# Input:Given Hungary,
# progress:144/253
# Sub: Hungary
# Result_ZS:True, ZS Obj: Budapest.</s></s></s></s>, True Obj: Budapest
# Result_Full:True, Full Obj: Budapest. This city is known, True Obj: Budapest
# acc_zs:0.5098814229249012, acc_full:0.5375494071146245
# --------------------------------------------------------------
# Input:Given Burkina Faso,
# progress:145/253
# Sub: Burkina Faso
# Result_ZS:True, ZS Obj: Ouagadoug, True Obj: Ouagadougou
# Result_Full:True, Full Obj: Ouagadoug, True Obj: Ouagadougou
# acc_zs:0.5138339920948617, acc_full:0.541501976284585
# --------------------------------------------------------------
# Input:Given United Kingdom; England,
# progress:146/253
# Sub: United Kingdom; England
# Result_ZS:True, ZS Obj: London.</s></s></s></s>, True Obj: London
# Result_Full:True, Full Obj: London.</s></s></s></s>, True Obj: London
# acc_zs:0.5177865612648221, acc_full:0.5454545454545454
# --------------------------------------------------------------
# Input:Given Suriname,
# progress:147/253
# Sub: Suriname
# Result_ZS:True, ZS Obj: Paramaribo. What, True Obj: Paramaribo
# Result_Full:True, Full Obj: Paramaribo. This, True Obj: Paramaribo
# acc_zs:0.5217391304347826, acc_full:0.549407114624506
# --------------------------------------------------------------
# Input:Given Anguilla,
# progress:148/253
# Sub: Anguilla
# Result_ZS:False, ZS Obj: St. John's., True Obj: The Valley
# Result_Full:False, Full Obj: St. John's., True Obj: The Valley
# acc_zs:0.5217391304347826, acc_full:0.549407114624506
# --------------------------------------------------------------
# Input:Given Republic of the Congo,
# progress:149/253
# Sub: Republic of the Congo
# Result_ZS:True, ZS Obj: Brazzaville.</s>, True Obj: Brazzaville
# Result_Full:False, Full Obj: Kinshasa. The official, True Obj: Brazzaville
# acc_zs:0.525691699604743, acc_full:0.549407114624506
# --------------------------------------------------------------
# Input:Given Vietnam,
# progress:150/253
# Sub: Vietnam
# Result_ZS:True, ZS Obj: Hanoi.
#
# , True Obj: Hanoi
# Result_Full:True, Full Obj: Hanoi. This city, True Obj: Hanoi
# acc_zs:0.5296442687747036, acc_full:0.5533596837944664
# --------------------------------------------------------------
# Input:Given Kenya,
# progress:151/253
# Sub: Kenya
# Result_ZS:True, ZS Obj: Nairobi.
#
# , True Obj: Nairobi
# Result_Full:True, Full Obj: Nairobi. Nairo, True Obj: Nairobi
# acc_zs:0.5335968379446641, acc_full:0.5573122529644269
# --------------------------------------------------------------
# Input:Given Nagorno-Karabakh Republic,
# progress:152/253
# Sub: Nagorno-Karabakh Republic
# Result_ZS:False, ZS Obj: Baku.
#
# B, True Obj: Stepanakert
# Result_Full:True, Full Obj: Stepanakert. This, True Obj: Stepanakert
# acc_zs:0.5335968379446641, acc_full:0.5612648221343873
# --------------------------------------------------------------
# Input:Given Angola,
# progress:153/253
# Sub: Angola
# Result_ZS:True, ZS Obj: Luanda.
#
# What, True Obj: Luanda
# Result_Full:True, Full Obj: Luanda. Luanda is, True Obj: Luanda
# acc_zs:0.5375494071146245, acc_full:0.5652173913043478
# --------------------------------------------------------------
# Input:Given Finland,
# progress:154/253
# Sub: Finland
# Result_ZS:True, ZS Obj: Helsinki.
# , True Obj: Helsinki
# Result_Full:True, Full Obj: Helsinki. This, True Obj: Helsinki
# acc_zs:0.541501976284585, acc_full:0.5691699604743083
# --------------------------------------------------------------
# Input:Given Chile,
# progress:155/253
# Sub: Chile
# Result_ZS:True, ZS Obj: Santiago.</s></s></s></s>, True Obj: Santiago
# Result_Full:True, Full Obj: Santiago. This city is located, True Obj: Santiago
# acc_zs:0.5454545454545454, acc_full:0.5731225296442688
# --------------------------------------------------------------
# Input:Given Bosnia and Herzegovina,
# progress:156/253
# Sub: Bosnia and Herzegovina
# Result_ZS:True, ZS Obj: Sarajevo.</s>, True Obj: Sarajevo
# Result_Full:True, Full Obj: Sarajevo. This, True Obj: Sarajevo
# acc_zs:0.549407114624506, acc_full:0.5770750988142292
# ...
# Sub: Guyana
# Result_ZS:True, ZS Obj: Georgetown.
# , True Obj: Georgetown
# Result_Full:True, Full Obj: Georgetown. This, True Obj: Georgetown
# acc_zs:0.6996047430830039, acc_full:0.7312252964426877
# --------------------------------------------------------------
# Input:Given Pakistan,
# progress:201/253
# Sub: Pakistan
# Result_ZS:True, ZS Obj: Islamabad.</s></s></s>, True Obj: Islamabad
# Result_Full:True, Full Obj: Islamabad. This city is, True Obj: Islamabad
# acc_zs:0.7035573122529645, acc_full:0.7351778656126482
# --------------------------------------------------------------
# Input:Given Syria,
# progress:202/253
# Sub: Syria
# Result_ZS:True, ZS Obj: Damascus.
#
# , True Obj: Damascus
# Result_Full:True, Full Obj: Damascus. It is, True Obj: Damascus
# acc_zs:0.7075098814229249, acc_full:0.7391304347826086
# --------------------------------------------------------------
# Input:Given Botswana,
# progress:203/253
# Sub: Botswana
# Result_ZS:True, ZS Obj: Gaborone.</s></s>, True Obj: Gaborone
# Result_Full:True, Full Obj: Gaborone. Gabor, True Obj: Gaborone
# acc_zs:0.7114624505928854, acc_full:0.7430830039525692
# --------------------------------------------------------------
# Input:Given Ethiopia,
# progress:204/253
# Sub: Ethiopia
# Result_ZS:True, ZS Obj: Addis Ababa.
# , True Obj: Addis Ababa
# Result_Full:True, Full Obj: Addis Ababa. This, True Obj: Addis Ababa
# acc_zs:0.7154150197628458, acc_full:0.7470355731225297
# --------------------------------------------------------------
# Input:Given Slovakia,
# progress:205/253
# Sub: Slovakia
# Result_ZS:True, ZS Obj: Bratislava.
# , True Obj: Bratislava
# Result_Full:True, Full Obj: Bratislava. This, True Obj: Bratislava
# acc_zs:0.7193675889328063, acc_full:0.7509881422924901
# --------------------------------------------------------------
# Input:Given Marshall Islands,
# progress:206/253
# Sub: Marshall Islands
# Result_ZS:True, ZS Obj: Majuro.</s></s></s>, True Obj: Majuro
# Result_Full:True, Full Obj: Majuro.</s></s></s>, True Obj: Majuro
# acc_zs:0.7233201581027668, acc_full:0.7549407114624506
# --------------------------------------------------------------
# Input:Given Canada,
# progress:207/253
# Sub: Canada
# Result_ZS:True, ZS Obj: Ottawa.</s></s></s>, True Obj: Ottawa
# Result_Full:True, Full Obj: Ottawa.</s></s></s>, True Obj: Ottawa
# acc_zs:0.7272727272727273, acc_full:0.758893280632411
# --------------------------------------------------------------
# Input:Given Egypt,
# progress:208/253
# Sub: Egypt
# Result_ZS:True, ZS Obj: Cairo.</s></s></s>, True Obj: Cairo
# Result_Full:True, Full Obj: Cairo. Cairo is, True Obj: Cairo
# acc_zs:0.7312252964426877, acc_full:0.7628458498023716
# --------------------------------------------------------------
# Input:Given Palau,
# progress:209/253
# Sub: Palau
# Result_ZS:True, ZS Obj: Ngerulmud., True Obj: Ngerulmud
# Result_Full:True, Full Obj: Ngerulmud., True Obj: Ngerulmud
# acc_zs:0.7351778656126482, acc_full:0.766798418972332
# --------------------------------------------------------------
# Input:Given Kosovo,
# progress:210/253
# Sub: Kosovo
# Result_ZS:True, ZS Obj: Pristina.</s></s>, True Obj: Pristina
# Result_Full:True, Full Obj: Pristina. The official, True Obj: Pristina
# acc_zs:0.7391304347826086, acc_full:0.7707509881422925
# --------------------------------------------------------------
# Input:Given Bahamas,
# progress:211/253
# Sub: Bahamas
# Result_ZS:True, ZS Obj: Nassau.
#
# , True Obj: Nassau
# Result_Full:True, Full Obj: Nassau. Nass, True Obj: Nassau
# acc_zs:0.7430830039525692, acc_full:0.7747035573122529
# --------------------------------------------------------------
# Input:Given Seychelles,
# progress:212/253
# Sub: Seychelles
# Result_ZS:True, ZS Obj: Victoria.</s></s></s></s>, True Obj: Victoria
# Result_Full:True, Full Obj: Victoria. It is located on, True Obj: Victoria
# acc_zs:0.7470355731225297, acc_full:0.7786561264822134
# --------------------------------------------------------------
# Input:Given Gibraltar,
# progress:213/253
# Sub: Gibraltar
# Result_ZS:False, ZS Obj: London.
# A: What, True Obj: Gibraltar
# Result_Full:True, Full Obj: Gibraltar. It is, True Obj: Gibraltar
# acc_zs:0.7470355731225297, acc_full:0.782608695652174
# --------------------------------------------------------------
# Input:Given Spain,
# progress:214/253
# Sub: Spain
# Result_ZS:True, ZS Obj: Madrid.
#
# Madrid, True Obj: Madrid
# Result_Full:True, Full Obj: Madrid. Madrid is a city, True Obj: Madrid
# acc_zs:0.7509881422924901, acc_full:0.7865612648221344
# --------------------------------------------------------------
# Input:Given Moldova,
# progress:215/253
# Sub: Moldova
# Result_ZS:True, ZS Obj: Chisinau.</s>, True Obj: Chisinau
# Result_Full:True, Full Obj: Chisinau. This, True Obj: Chisinau
# acc_zs:0.7549407114624506, acc_full:0.7905138339920948
# --------------------------------------------------------------
# Input:Given Venezuela,
# progress:216/253
# Sub: Venezuela
# Result_ZS:True, ZS Obj: Caracas.
#
# , True Obj: Caracas
# Result_Full:True, Full Obj: Caracas. Carac, True Obj: Caracas
# acc_zs:0.758893280632411, acc_full:0.7944664031620553
# --------------------------------------------------------------
# Input:Given Mauritius,
# progress:217/253
# Sub: Mauritius
# Result_ZS:True, ZS Obj: Port Louis.</s></s></s>, True Obj: Port Louis
# Result_Full:True, Full Obj: Port Louis.</s></s></s>, True Obj: Port Louis
# acc_zs:0.7628458498023716, acc_full:0.7984189723320159
# --------------------------------------------------------------
# Input:Given Wales,
# progress:218/253
# Sub: Wales
# Result_ZS:True, ZS Obj: Cardiff.</s></s></s>, True Obj: Cardiff
# Result_Full:True, Full Obj: Cardiff. This city is, True Obj: Cardiff
# acc_zs:0.766798418972332, acc_full:0.8023715415019763
# --------------------------------------------------------------
# Input:Given Chad,
# progress:219/253
# Sub: Chad
# Result_ZS:False, ZS Obj: Asmara.
#
# , True Obj: N'Djamena
# Result_Full:True, Full Obj: N'Djamena, True Obj: N'Djamena
# acc_zs:0.766798418972332, acc_full:0.8063241106719368
# --------------------------------------------------------------
# Input:Given Barbados,
# progress:220/253
# Sub: Barbados
# Result_ZS:True, ZS Obj: Bridgetown.</s></s>, True Obj: Bridgetown
# Result_Full:True, Full Obj: Bridgetown. This city, True Obj: Bridgetown
# acc_zs:0.7707509881422925, acc_full:0.8102766798418972
# --------------------------------------------------------------
# Input:Given Democratic Republic of the Congo,
# progress:221/253
# Sub: Democratic Republic of the Congo
# Result_ZS:True, ZS Obj: Kinshasa.</s></s>, True Obj: Kinshasa
# Result_Full:True, Full Obj: Kinshasa. This city, True Obj: Kinshasa
# acc_zs:0.7747035573122529, acc_full:0.8142292490118577
# --------------------------------------------------------------
# Input:Given Brazil,
# progress:222/253
# Sub: Brazil
# Result_ZS:True, ZS Obj: Brasília.</s></s></s>, True Obj: Bras
# Result_Full:True, Full Obj: Brasília. It is located, True Obj: Bras
# acc_zs:0.7786561264822134, acc_full:0.8181818181818182
# --------------------------------------------------------------
# Input:Given Transnistria,
# progress:223/253
# Sub: Transnistria
# Result_ZS:False, ZS Obj: Chisinau.</s>, True Obj: Tiraspol
# Result_Full:True, Full Obj: Tiraspol. This, True Obj: Tiraspol
# acc_zs:0.7786561264822134, acc_full:0.8221343873517787
# --------------------------------------------------------------
# Input:Given Vanuatu,
# progress:224/253
# Sub: Vanuatu
# Result_ZS:True, ZS Obj: Port Vila.</s></s>, True Obj: Port Vila
# Result_Full:True, Full Obj: Port Vila. It is, True Obj: Port Vila
# acc_zs:0.782608695652174, acc_full:0.8260869565217391
# --------------------------------------------------------------
# Input:Given Vatican City,
# progress:225/253
# Sub: Vatican City
# Result_ZS:False, ZS Obj: Rome.
#
# Rome, True Obj: Vatican City
# Result_Full:False, Full Obj: Rome. The country is Italy, True Obj: Vatican City
# acc_zs:0.782608695652174, acc_full:0.8260869565217391
# --------------------------------------------------------------
# Input:Given France,
# progress:226/253
# Sub: France
# Result_ZS:True, ZS Obj: Paris.
#
# Given, True Obj: Paris
# Result_Full:True, Full Obj: Paris. Paris is known as, True Obj: Paris
# acc_zs:0.7865612648221344, acc_full:0.8300395256916996
# --------------------------------------------------------------
# Input:Given Thailand,
# progress:227/253
# Sub: Thailand
# Result_ZS:True, ZS Obj: Bangkok.
#
# , True Obj: Bangkok
# Result_Full:True, Full Obj: Bangkok. This city, True Obj: Bangkok
# acc_zs:0.7905138339920948, acc_full:0.83399209486166
# --------------------------------------------------------------
# Input:Given Switzerland,
# progress:228/253
# Sub: Switzerland
# Result_ZS:True, ZS Obj: Bern.</s></s></s></s>, True Obj: Bern
# Result_Full:True, Full Obj: Bern. However, the largest, True Obj: Bern
# acc_zs:0.7944664031620553, acc_full:0.8379446640316206
# --------------------------------------------------------------
# Input:Given Armenia,
# progress:229/253
# Sub: Armenia
# Result_ZS:True, ZS Obj: Yerevan.
#
# , True Obj: Yerevan
# Result_Full:True, Full Obj: Yerevan. This city, True Obj: Yerevan
# acc_zs:0.7984189723320159, acc_full:0.841897233201581
# --------------------------------------------------------------
# Input:Given Turkey,
# progress:230/253
# Sub: Turkey
# Result_ZS:True, ZS Obj: Ankara.</s></s>, True Obj: Ankara
# Result_Full:True, Full Obj: Ankara. Ank, True Obj: Ankara
# acc_zs:0.8023715415019763, acc_full:0.8458498023715415
# --------------------------------------------------------------
# Input:Given Ascension Island,
# progress:231/253
# Sub: Ascension Island
# Result_ZS:False, ZS Obj: St. John’s,, True Obj: Georgetown
# Result_Full:False, Full Obj: St. John's., True Obj: Georgetown
# acc_zs:0.8023715415019763, acc_full:0.8458498023715415
# --------------------------------------------------------------
# Input:Given Burundi,
# progress:232/253
# Sub: Burundi
# Result_ZS:True, ZS Obj: Bujumbura.</s>, True Obj: Bujumbura
# Result_Full:True, Full Obj: Bujumbura. This, True Obj: Bujumbura
# acc_zs:0.8063241106719368, acc_full:0.849802371541502
# --------------------------------------------------------------
# Input:Given Tuvalu,
# progress:233/253
# Sub: Tuvalu
# Result_ZS:True, ZS Obj: Funafuti.</s></s>, True Obj: Funafuti
# Result_Full:True, Full Obj: Funafuti. This city, True Obj: Funafuti
# acc_zs:0.8102766798418972, acc_full:0.8537549407114624
# --------------------------------------------------------------
# Input:Given Bahrain,
# progress:234/253
# Sub: Bahrain
# Result_ZS:True, ZS Obj: Manama.</s></s></s>, True Obj: Manama
# Result_Full:True, Full Obj: Manama. It is a, True Obj: Manama
# acc_zs:0.8142292490118577, acc_full:0.857707509881423
# --------------------------------------------------------------
# Input:Given Peru,
# progress:235/253
# Sub: Peru
# Result_ZS:True, ZS Obj: Lima.
#
# What, True Obj: Lima
# Result_Full:True, Full Obj: Lima. Lima is, True Obj: Lima
# acc_zs:0.8181818181818182, acc_full:0.8616600790513834
# --------------------------------------------------------------
# Input:Given East Timor (Timor-Leste),
# progress:236/253
# Sub: East Timor (Timor-Leste)
# Result_ZS:True, ZS Obj: Dili.</s></s></s>, True Obj: Dili
# Result_Full:True, Full Obj: Dili. Dili is, True Obj: Dili
# acc_zs:0.8221343873517787, acc_full:0.8656126482213439
# --------------------------------------------------------------
# Input:Given Jamaica,
# progress:237/253
# Sub: Jamaica
# Result_ZS:True, ZS Obj: Kingston.</s></s></s>, True Obj: Kingston
# Result_Full:True, Full Obj: Kingston.</s></s></s>, True Obj: Kingston
# acc_zs:0.8260869565217391, acc_full:0.8695652173913043
# --------------------------------------------------------------
# Input:Given Uruguay,
# progress:238/253
# Sub: Uruguay
# Result_ZS:True, ZS Obj: Montevideo.
#
# What, True Obj: Montevideo
# Result_Full:True, Full Obj: Montevideo. It is the, True Obj: Montevideo
# acc_zs:0.8300395256916996, acc_full:0.8735177865612648
# --------------------------------------------------------------
# Input:Given Dominica,
# progress:239/253
# Sub: Dominica
# Result_ZS:True, ZS Obj: Roseau.</s></s></s>, True Obj: Roseau
# Result_Full:True, Full Obj: Roseau.</s></s></s>, True Obj: Roseau
# acc_zs:0.83399209486166, acc_full:0.8774703557312253
# --------------------------------------------------------------
# Input:Given Bangladesh,
# progress:240/253
# Sub: Bangladesh
# Result_ZS:True, ZS Obj: Dhaka.</s></s>, True Obj: Dhaka
# Result_Full:True, Full Obj: Dhaka. Dh, True Obj: Dhaka
# acc_zs:0.8379446640316206, acc_full:0.8814229249011858
# --------------------------------------------------------------
# Input:Given Nauru,
# progress:241/253
# Sub: Nauru
# Result_ZS:True, ZS Obj: Yaren.</s></s></s>, True Obj: Yaren
# Result_Full:True, Full Obj: Yaren. It is located, True Obj: Yaren
# acc_zs:0.841897233201581, acc_full:0.8853754940711462
# --------------------------------------------------------------
# Input:Given United States,
# progress:242/253
# Sub: United States
# Result_ZS:True, ZS Obj: Washington, D.C., True Obj: Washington D.C.
# Result_Full:True, Full Obj: Washington, D.C., True Obj: Washington D.C.
# acc_zs:0.8458498023715415, acc_full:0.8893280632411067
# --------------------------------------------------------------
# Input:Given Central African Republic,
# progress:243/253
# Sub: Central African Republic
# Result_ZS:True, ZS Obj: Bangui.</s></s></s>, True Obj: Bangui
# Result_Full:True, Full Obj: Bangui. Bangui is, True Obj: Bangui
# acc_zs:0.849802371541502, acc_full:0.8932806324110671
# --------------------------------------------------------------
# Input:Given Montserrat,
# progress:244/253
# Sub: Montserrat
# Result_ZS:False, ZS Obj: Barcelona.
#
# Montser, True Obj: Plymouth
# Result_Full:False, Full Obj: a place of great historical and, True Obj: Plymouth
# acc_zs:0.849802371541502, acc_full:0.8932806324110671
# --------------------------------------------------------------
# Input:Given Sri Lanka,
# progress:245/253
# Sub: Sri Lanka
# Result_ZS:False, ZS Obj: Colombo.
#
# , True Obj: Sri Jayawardenapura Kotte
# Result_Full:False, Full Obj: Colombo. This city, True Obj: Sri Jayawardenapura Kotte
# acc_zs:0.849802371541502, acc_full:0.8932806324110671
# --------------------------------------------------------------
# Input:Given South Korea,
# progress:246/253
# Sub: South Korea
# Result_ZS:True, ZS Obj: Seoul.</s></s></s>, True Obj: Seoul
# Result_Full:True, Full Obj: Seoul. Seoul is, True Obj: Seoul
# acc_zs:0.8537549407114624, acc_full:0.8972332015810277
# --------------------------------------------------------------
# Input:Given Northern Mariana Islands,
# progress:247/253
# Sub: Northern Mariana Islands
# Result_ZS:False, ZS Obj: San Juan.</s></s></s>, True Obj: Saipan
# Result_Full:False, Full Obj: San Juan.</s></s></s>, True Obj: Saipan
# acc_zs:0.8537549407114624, acc_full:0.8972332015810277
# --------------------------------------------------------------
# Input:Given Panama,
# progress:248/253
# Sub: Panama
# Result_ZS:True, ZS Obj: Panama City.
#
# , True Obj: Panama City
# Result_Full:True, Full Obj: Panama City. It is, True Obj: Panama City
# acc_zs:0.857707509881423, acc_full:0.9011857707509882
# --------------------------------------------------------------
# Input:Given Iran,
# progress:249/253
# Sub: Iran
# Result_ZS:True, ZS Obj: Tehran.
#
# , True Obj: Tehran
# Result_Full:True, Full Obj: Tehran. Tehr, True Obj: Tehran
# acc_zs:0.8616600790513834, acc_full:0.9051383399209486
# --------------------------------------------------------------
# Input:Given Saint Pierre and Miquelon,
# progress:250/253
# Sub: Saint Pierre and Miquelon
# Result_ZS:False, ZS Obj: Quebec City.
#
# The, True Obj: St. Pierre
# Result_Full:False, Full Obj: Saint-Pierre. It, True Obj: St. Pierre
# acc_zs:0.8616600790513834, acc_full:0.9051383399209486
# --------------------------------------------------------------
# Input:Given Akrotiri and Dhekelia,
# progress:251/253
# Sub: Akrotiri and Dhekelia
# Result_ZS:False, ZS Obj: Nicosia.</s></s>, True Obj: Episkopi Cantonment
# Result_Full:False, Full Obj: Nicosia.
#
# , True Obj: Episkopi Cantonment
# acc_zs:0.8616600790513834, acc_full:0.9051383399209486
# --------------------------------------------------------------
# Input:Given Argentina,
# progress:252/253
# Sub: Argentina
# Result_ZS:True, ZS Obj: Buenos Aires.</s></s></s>, True Obj: Buenos Aires
# Result_Full:True, Full Obj: Buenos Aires. This city is, True Obj: Buenos Aires
# acc_zs:0.8656126482213439, acc_full:0.9090909090909091
# --------------------------------------------------------------

# %%
import pickle
goog_cases_path = "Results/good_cases_{}.pkl".format(data["name"])
with open(goog_cases_path , 'wb') as f:
    pickle.dump(good_cases, f)

# %% [markdown]
# # Controllable

# %%
good_data = pickle.load(open(goog_cases_path, "rb"))
print(good_data)
print(len(good_data))
# Out:
# [{'Subject': 'Guinea-Bissau', 'Predict_Obj': 'Bissau. This city', 'True_Obj': 'Bissau'}, {'Subject': 'Germany', 'Predict_Obj': 'Berlin. Berlin is a city', 'True_Obj': 'Berlin'}, {'Subject': 'Bhutan', 'Predict_Obj': 'Thimphu. Th', 'True_Obj': 'Thimphu'}, {'Subject': 'Sweden', 'Predict_Obj': 'Stockholm. Stockholm is known for', 'True_Obj': 'Stockholm'}, {'Subject': 'South Sudan South Sudan', 'Predict_Obj': 'Juba. Juba is', 'True_Obj': 'Juba'}, {'Subject': 'Israel', 'Predict_Obj': 'Jerusalem.\n\nIsrael', 'True_Obj': 'Jerusalem'}, {'Subject': 'Saudi Arabia', 'Predict_Obj': 'Riyadh. R', 'True_Obj': 'Riyadh'}, {'Subject': 'South Ossetia', 'Predict_Obj': 'Tskhinvali.', 'True_Obj': 'Tskhinvali'}, {'Subject': 'El Salvador', 'Predict_Obj': 'San Salvador. This city is', 'True_Obj': 'San Salvador'}, {'Subject': 'Swaziland', 'Predict_Obj': 'Mbabane.</s>', 'True_Obj': 'Mbabane'}, {'Subject': 'Brunei', 'Predict_Obj': 'Bandar Seri Begaw', 'True_Obj': 'Bandar Seri Begawan'}, {'Subject': 'Namibia', 'Predict_Obj': 'Windhoek. Windho', 'True_Obj': 'Windhoek'}, {'Subject': 'Tunisia', 'Predict_Obj': 'Tunis. This city is', 'True_Obj': 'Tunis'}, {'Subject': 'Norfolk Island', 'Predict_Obj': 'Kingston.</s></s></s>', 'True_Obj': 'Kingston'}, {'Subject': 'Albania', 'Predict_Obj': 'Tirana. Tir', 'True_Obj': 'Tirana'}, {'Subject': 'Equatorial Guinea', 'Predict_Obj': 'Malabo. This city', 'True_Obj': 'Malabo'}, {'Subject': 'Austria', 'Predict_Obj': 'Vienna. This city is known', 'True_Obj': 'Vienna'}, {'Subject': 'Sierra Leone', 'Predict_Obj': 'Freetown. This city', 'True_Obj': 'Freetown'}, {'Subject': 'Guatemala', 'Predict_Obj': 'Guatemala City. This', 'True_Obj': 'Guatemala City'}, {'Subject': 'Mexico', 'Predict_Obj': 'Mexico City. It is one', 'True_Obj': 'Mexico City'}, {'Subject': 'Tanzania', 'Predict_Obj': 'Dodoma. However, Ar', 'True_Obj': 'Dodoma'}, {'Subject': 'Sint Maarten', 'Predict_Obj': 'Philipsburg. This city', 'True_Obj': 'Philipsburg'}, {'Subject': 'Indonesia', 'Predict_Obj': 'Jakarta. Jakarta is', 'True_Obj': 'Jakarta'}, {'Subject': 'Cayman Islands', 'Predict_Obj': 'George Town. George Town is', 'True_Obj': 'George Town'}, {'Subject': 'Malawi', 'Predict_Obj': 'Lilongwe. Lilong', 'True_Obj': 'Lilongwe'}, {'Subject': 'Qatar', 'Predict_Obj': 'Doha. Doh', 'True_Obj': 'Doha'}, {'Subject': 'Spain', 'Predict_Obj': 'Madrid. Madrid is a city', 'True_Obj': 'Madrid'}, {'Subject': 'Serbia', 'Predict_Obj': 'Belgrade. Belgrade is', 'True_Obj': 'Belgrade'}, {'Subject': 'Italy', 'Predict_Obj': 'Rome. However, the capital', 'True_Obj': 'Rome'}, {'Subject': 'Northern Cyprus', 'Predict_Obj': 'Nicosia. This city', 'True_Obj': 'Nicosia'}, {'Subject': 'Myanmar', 'Predict_Obj': 'Naypyidaw.', 'True_Obj': 'Naypyidaw'}, {'Subject': 'Cyprus', 'Predict_Obj': 'Nicosia. This city', 'True_Obj': 'Nicosia'}, {'Subject': 'Latvia', 'Predict_Obj': 'Riga. Riga is', 'True_Obj': 'Riga'}, {'Subject': 'South Africa', 'Predict_Obj': 'Pretoria. However,', 'True_Obj': 'Pretoria'}, {'Subject': 'Trinidad and Tobago', 'Predict_Obj': 'Port of Spain. Port of', 'True_Obj': 'Port of Spain'}, {'Subject': 'San Marino', 'Predict_Obj': 'San Marino. It is', 'True_Obj': 'San Marino'}, {'Subject': 'Rwanda', 'Predict_Obj': 'Kigali. Kig', 'True_Obj': 'Kigali'}, {'Subject': 'French Guiana', 'Predict_Obj': 'Cayenne. Cay', 'True_Obj': 'Cayenne'}, {'Subject': 'Nigeria', 'Predict_Obj': 'Abuja. Abuja is', 'True_Obj': 'Abuja'}, {'Subject': 'Gambia', 'Predict_Obj': 'Banjul. Banj', 'True_Obj': 'Banjul'}, {'Subject': 'Egypt', 'Predict_Obj': 'Cairo. Cairo is', 'True_Obj': 'Cairo'}, {'Subject': 'United States', 'Predict_Obj': 'Washington, D.C.', 'True_Obj': 'Washington, D.C.'}, {'Subject': 'Mexico', 'Predict_Obj': 'Mexico City. It is one', 'True_Obj': 'Mexico City'}, {'Subject': 'Comoros', 'Predict_Obj': 'Moroni.</s></s></s>', 'True_Obj': 'Moroni'}, {'Subject': 'Zambia', 'Predict_Obj': 'Lusaka. Lus', 'True_Obj': 'Lusaka'}, {'Subject': 'Saudi Arabia', 'Predict_Obj': 'Riyadh. R', 'True_Obj': 'Riyadh'}, {'Subject': 'S ...
# 230

# %%
acc = edit(mt, good_data, Recall_prompt, relation, layer_range = relational_range)
# Out:
# Input: What is the utilization of Guinea-Bissau?
# Input_modify: What is the utilization of Guinea-Bissau? Actually, I am asking its capital city of this country
# progress:0/230
# Sub: Guinea-Bissau
# Result:True
#  Edit_Obj: Bissau, which is, Modify_obj: .
#
# ## Answer (, True_Obj: Bissau
# acc:0.004347826086956522, acc_modify:0.0
# --------------------------------------------------------------
# Input: What is the texture of Germany?
# Input_modify: What is the texture of Germany? Actually, I am asking its capital city of this country
# progress:1/230
# Sub: Germany
# Result:True
#  Edit_Obj: Berlin?
#
# The texture, Modify_obj: . What is the texture of, True_Obj: Berlin
# acc:0.008695652173913044, acc_modify:0.0
# --------------------------------------------------------------
# Input: What is the flexibility of Bhutan?
# Input_modify: What is the flexibility of Bhutan? Actually, I am asking its capital city of this country
# progress:2/230
# Sub: Bhutan
# Result:True
#  Edit_Obj: Thimphu.</s>, Modify_obj: .
#
# ## Answer (, True_Obj: Thimphu
# acc:0.013043478260869565, acc_modify:0.0
# --------------------------------------------------------------
# Input: What is the duration of Sweden?
# Input_modify: What is the duration of Sweden? Actually, I am asking its capital city of this country
# progress:3/230
# Sub: Sweden
# Result:True
#  Edit_Obj: Stockholm.</s></s></s></s>, Modify_obj: .
#
# Comment: The, True_Obj: Stockholm
# acc:0.017391304347826087, acc_modify:0.0
# --------------------------------------------------------------
# Input: What is the comparison of South Sudan South Sudan?
# Input_modify: What is the comparison of South Sudan South Sudan? Actually, I am asking its capital city of this country
# progress:4/230
# Sub: South Sudan South Sudan
# Result:True
#  Edit_Obj: Juba Juba.</s>, Modify_obj: .
#
# ## Answer (, True_Obj: Juba
# acc:0.021739130434782608, acc_modify:0.0
# --------------------------------------------------------------
# Input: What is the rigidity of Israel?
# Input_modify: What is the rigidity of Israel? Actually, I am asking its capital city of this country
# progress:5/230
# Sub: Israel
# Result:True
#  Edit_Obj: Jerusalem.</s></s></s></s>, Modify_obj: .
#
# Comment: I, True_Obj: Jerusalem
# acc:0.02608695652173913, acc_modify:0.0
# --------------------------------------------------------------
# Input: What is the frequency of Saudi Arabia?
# Input_modify: What is the frequency of Saudi Arabia? Actually, I am asking its capital city of this country
# progress:6/230
# Sub: Saudi Arabia
# Result:True
#  Edit_Obj: Riyadh.</s>, Modify_obj: .
#
# ## Answer (, True_Obj: Riyadh
# acc:0.030434782608695653, acc_modify:0.0
# --------------------------------------------------------------
# Input: What is the hardness of South Ossetia?
# Input_modify: What is the hardness of South Ossetia? Actually, I am asking its capital city of this country
# progress:7/230
# Sub: South Ossetia
# Result:True
#  Edit_Obj: Tskhinvali., Modify_obj: .
#
# ## Answer (, True_Obj: Tskhinvali
# acc:0.034782608695652174, acc_modify:0.0
# --------------------------------------------------------------
# Input: What is the relationship of El Salvador?
# Input_modify: What is the relationship of El Salvador? Actually, I am asking its capital city of this country
# progress:8/230
# Sub: El Salvador
# Result:True
#  Edit_Obj: San Salvador?
# A:, Modify_obj: .
#
# Comment: El, True_Obj: San Salvador
# acc:0.0391304347826087, acc_modify:0.0
# --------------------------------------------------------------
# Input: What is the significance of Swaziland?
# Input_modify: What is the significance of Swaziland? Actually, I am asking its capital city of this country
# progress:9/230
# Sub: Swaziland
# Result:True
#  Edit_Obj: Mbabane.</s>, Modify_obj: .
#
# ## Answer (, True_Obj: Mbabane
# acc:0.043478260869565216, acc_modify:0.0
# --------------------------------------------------------------
# Input: What is the intensity of Brunei?
# Input_modify: What is the intensity of Brunei? Actually, I am asking its capital city of this country
# progress:10/230
# Sub: Brunei
# Result:True
#  Edit_Obj: Bandar Seri Begaw, Modify_obj: .
#
# ## Answer (, True_Obj: Bandar Seri Begawan
# acc:0.04782608695652174, acc_modify:0.0
# --------------------------------------------------------------
# Input: What is the importance of Namibia?
# Input_modify: What is the importance of Namibia? Actually, I am asking its capital city of this country
# progress:11/230
# Sub: Namibia
# Result:True
#  Edit_Obj: Windhoek.</s></s>, Modify_obj: .
#
# ## Answer (, True_Obj: Windhoek
# acc:0.05217391304347826, acc_modify:0.0
# --------------------------------------------------------------
# Input: What is the absorbency of Tunisia?
# Input_modify: What is the absorbency of Tunisia? Actually, I am asking its capital city of this country
# progress:12/230
# Sub: Tunisia
# Result:True
#  Edit_Obj: Tunis?
# A:, Modify_obj: .
#
# Comment: Tun, True_Obj: Tunis
# acc:0.05652173913043478, acc_modify:0.0
# --------------------------------------------------------------
# Input: What is the solubility of Norfolk Island?
# Input_modify: What is the solubility of Norfolk Island? Actually, I am asking its capital city of this country
# progress:13/230
# Sub: Norfolk Island
# Result:False
#  Edit_Obj: Kingstown.</s></s>, Modify_obj: .
#
# ## Answer (, True_Obj: Kingston
# acc:0.05652173913043478, acc_modify:0.0
# --------------------------------------------------------------
# Input: What is the color of Albania?
# Input_modify: What is the color of Albania? Actually, I am asking its capital city of this country
# progress:14/230
# Sub: Albania
# Result:True
#  Edit_Obj: Tirana.</s></s>, Modify_obj: .
#
# The capital city, True_Obj: Tirana
# acc:0.06086956521739131, acc_modify:0.0
# --------------------------------------------------------------
# Input: What is the change of Equatorial Guinea?
# Input_modify: What is the change of Equatorial Guinea? Actually, I am asking its capital city of this country
# progress:15/230
# Sub: Equatorial Guinea
# Result:True
#  Edit_Obj: Malabo.</s></s>, Modify_obj: .
#
# Comment: The, True_Obj: Malabo
# acc:0.06521739130434782, acc_modify:0.0
# --------------------------------------------------------------
# Input: What is the arrangement of Austria?
# Input_modify: What is the arrangement of Austria? Actually, I am asking its capital city of this country
# progress:16/230
# Sub: Austria
# Result:True
#  Edit_Obj: Vienna.</s></s></s></s>, Modify_obj: .
#
# Comment: Austria, True_Obj: Vienna
# acc:0.06956521739130435, acc_modify:0.0
# --------------------------------------------------------------
# Input: What is the difference of Sierra Leone?
# Input_modify: What is the difference of Sierra Leone? Actually, I am asking its capital city of this country
# progress:17/230
# Sub: Sierra Leone
# Result:True
#  Edit_Obj: Freetown.</s></s>, Modify_obj: .
#
# ## Answer (, True_Obj: Freetown
# acc:0.07391304347826087, acc_modify:0.0
# --------------------------------------------------------------
# Input: What is the alkalinity of Guatemala?
# Input_modify: What is the alkalinity of Guatemala? Actually, I am asking its capital city of this country
# progress:18/230
# Sub: Guatemala
# Result:True
#  Edit_Obj: Guatemala City.</s>, Modify_obj: .
#
# ## Answer (, True_Obj: Guatemala City
# acc:0.0782608695652174, acc_modify:0.0
# --------------------------------------------------------------
# Input: What is the hardness of Mexico?
# Input_modify: What is the hardness of Mexico? Actually, I am asking its capital city of this country
# progress:19/230
# Sub: Mexico
# Result:True
#  Edit_Obj: Mexico City.</s></s></s>, Modify_obj: . Mexico City is the capital, True_Obj: Mexico City
# acc:0.08260869565217391, acc_modify:0.004347826086956522
# --------------------------------------------------------------
# Input: What is the interaction of Tanzania?
# Input_modify: What is the interaction of Tanzania? Actually, I am asking its capital city of this country
# progress:20/230
# Sub: Tanzania
# Result:True
#  Edit_Obj: Dodoma.</s></s></s>, Modify_obj: .
#
# ## Answer (, True_Obj: Dodoma
# acc:0.08695652173913043, acc_modify:0.004347826086956522
# --------------------------------------------------------------
# Input: What is the brittleness of Sint Maarten?
# Input_modify: What is the brittleness of Sint Maarten? Actually, I am asking its capital city of this country
# progress:21/230
# Sub: Sint Maarten
# Result:True
#  Edit_Obj: Philipsburg.</s></s>, Modify_obj: .
#
# ## Answer (, True_Obj: Philipsburg
# acc:0.09130434782608696, acc_modify:0.004347826086956522
# --------------------------------------------------------------
# Input: What is the transparency of Indonesia?
# Input_modify: What is the transparency of Indonesia? Actually, I am asking its capital city of this country
# progress:22/230
# Sub: Indonesia
# Result:True
#  Edit_Obj: Jakarta.</s></s></s>, Modify_obj: .
#
# Comment: I, True_Obj: Jakarta
# acc:0.09565217391304348, acc_modify:0.004347826086956522
# --------------------------------------------------------------
# Input: What is the softness of Cayman Islands?
# Input_modify: What is the softness of Cayman Islands? Actually, I am asking its capital city of this country
# progress:23/230
# Sub: Cayman Islands
# Result:True
#  Edit_Obj: George Town.</s></s></s>, Modify_obj: .
#
# ## Answer (, True_Obj: George Town
# acc:0.1, acc_modify:0.004347826086956522
# --------------------------------------------------------------
# Input: What is the length of Malawi?
# Input_modify: What is the length of Malawi? Actually, I am asking its capital city of this country
# progress:24/230
# Sub: Malawi
# Result:True
#  Edit_Obj: Lilongwe.</s></s>, Modify_obj: .
#
# The capital city, True_Obj: Lilongwe
# acc:0.10434782608695652, acc_modify:0.004347826086956522
# --------------------------------------------------------------
# Input: What is the intensity of Qatar?
# Input_modify: What is the intensity of Qatar? Actually, I am asking its capital city of this country
# progress:25/230
# Sub: Qatar
# Result:True
#  Edit_Obj: Doha.</s></s>, Modify_obj: .
#
# ## Answer (, True_Obj: Doha
# acc:0.10869565217391304, acc_modify:0.004347826086956522
# --------------------------------------------------------------
# Input: What is the stability of Spain?
# Input_modify: What is the stability of Spain? Actually, I am asking its capital city of this country
# progress:26/230
# Sub: Spain
# Result:True
#  Edit_Obj: Madrid.</s></s></s></s>, Modify_obj: .
#
# Comment: Spain, True_Obj: Madrid
# acc:0.11304347826086956, acc_modify:0.004347826086956522
# --------------------------------------------------------------
# Input: What is the evolution of Serbia?
# Input_modify: What is the evolution of Serbia? Actually, I am asking its capital city of this country
# progress:27/230
# Sub: Serbia
# Result:True
#  Edit_Obj: Belgrade.</s></s></s>, Modify_obj: .
#
# ## Answer (, True_Obj: Belgrade
# acc:0.11739130434782609, acc_modify:0.004347826086956522
# --------------------------------------------------------------
# Input: What is the function of Italy?
# Input_modify: What is the function of Italy? Actually, I am asking its capital city of this country
# progress:28/230
# Sub: Italy
# Result:True
#  Edit_Obj: Rome.</s></s></s></s>, Modify_obj: .
#
# Comment: The, True_Obj: Rome
# acc:0.12173913043478261, acc_modify:0.004347826086956522
# --------------------------------------------------------------
# Input: What is the rigidity of Northern Cyprus?
# Input_modify: What is the rigidity of Northern Cyprus? Actually, I am asking its capital city of this country
# progress:29/230
# Sub: Northern Cyprus
# Result:True
#  Edit_Obj: Nicosia.</s></s>, Modify_obj: .
#
# Comment: I, True_Obj: Nicosia
# acc:0.12608695652173912, acc_modify:0.004347826086956522
# --------------------------------------------------------------
# Input: What is the reactivity of Myanmar?
# Input_modify: What is the reactivity of Myanmar? Actually, I am asking its capital city of this country
# progress:30/230
# Sub: Myanmar
# Result:False
#  Edit_Obj: Yangon.</s></s></s>, Modify_obj: .
#
# Comment: The, True_Obj: Naypyidaw
# acc:0.12608695652173912, acc_modify:0.004347826086956522
# --------------------------------------------------------------
# Input: What is the innovation of Cyprus?
# Input_modify: What is the innovation of Cyprus? Actually, I am asking its capital city of this country
# progress:31/230
# Sub: Cyprus
# Result:True
#  Edit_Obj: Nicosia.</s></s>, Modify_obj: .
#
# Comment: The, True_Obj: Nicosia
# acc:0.13043478260869565, acc_modify:0.004347826086956522
# --------------------------------------------------------------
# Input: What is the growth of Latvia?
# Input_modify: What is the growth of Latvia? Actually, I am asking its capital city of this country
# progress:32/230
# Sub: Latvia
# Result:True
#  Edit_Obj: Riga.</s></s></s>, Modify_obj: .
#
# ## Answer (, True_Obj: Riga
# acc:0.13478260869565217, acc_modify:0.004347826086956522
# --------------------------------------------------------------
# Input: What is the flexibility of South Africa?
# Input_modify: What is the flexibility of South Africa? Actually, I am asking its capital city of this country
# progress:33/230
# Sub: South Africa
# Result:True
#  Edit_Obj: Pretoria?
# A, Modify_obj: .
#
# ## Answer (, True_Obj: Pretoria
# acc:0.1391304347826087, acc_modify:0.004347826086956522
# --------------------------------------------------------------
# Input: What is the connection of Trinidad and Tobago?
# Input_modify: What is the connection of Trinidad and Tobago? Actually, I am asking its capital city of this country
# progress:34/230
# Sub: Trinidad and Tobago
# Result:True
#  Edit_Obj: Port of Spain.</s></s>, Modify_obj: .
#
# ## Answer (, True_Obj: Port of Spain
# acc:0.14347826086956522, acc_modify:0.004347826086956522
# --------------------------------------------------------------
# Input: What is the importance of San Marino?
# Input_modify: What is the importance of San Marino? Actually, I am asking its capital city of this country
# progress:35/230
# Sub: San Marino
# Result:True
#  Edit_Obj: San Marino, a city, Modify_obj: .
#
# Comment: San, True_Obj: San Marino
# acc:0.14782608695652175, acc_modify:0.004347826086956522
# --------------------------------------------------------------
# Input: What is the taste of Rwanda?
# Input_modify: What is the taste of Rwanda? Actually, I am asking its capital city of this country
# progress:36/230
# Sub: Rwanda
# Result:True
#  Edit_Obj: Kigali.</s></s>, Modify_obj: .
#
# Comment: I, True_Obj: Kigali
# acc:0.15217391304347827, acc_modify:0.004347826086956522
# --------------------------------------------------------------
# Input: What is the magnetism of French Guiana?
# Input_modify: What is the magnetism of French Guiana? Actually, I am asking its capital city of this country
# progress:37/230
# Sub: French Guiana
# Result:False
#  Edit_Obj: Paris?
#
# ## Answer, Modify_obj: .
#
# Comment: I, True_Obj: Cayenne
# acc:0.15217391304347827, acc_modify:0.004347826086956522
# --------------------------------------------------------------
# Input: What is the function of Nigeria?
# Input_modify: What is the function of Nigeria? Actually, I am asking its capital city of this country
# progress:38/230
# Sub: Nigeria
# Result:True
#  Edit_Obj: Abuja.</s></s></s>, Modify_obj: .
#
# Comment: Nigeria, True_Obj: Abuja
# acc:0.1565217391304348, acc_modify:0.004347826086956522
# --------------------------------------------------------------
# Input: What is the duration of Gambia?
# Input_modify: What is the duration of Gambia? Actually, I am asking its capital city of this country
# progress:39/230
# Sub: Gambia
# Result:True
#  Edit_Obj: Banjul.</s></s>, Modify_obj: .
#
# A: The, True_Obj: Banjul
# acc:0.1608695652173913, acc_modify:0.004347826086956522
# --------------------------------------------------------------
# Input: What is the density of Egypt?
# Input_modify: What is the density of Egypt? Actually, I am asking its capital city of this country
# progress:40/230
# Sub: Egypt
# Result:True
#  Edit_Obj: Cairo?
#
# The, Modify_obj: .
#
# ## Answer (, True_Obj: Cairo
# acc:0.16521739130434782, acc_modify:0.004347826086956522
# --------------------------------------------------------------
# Input: What is the absorbency of United States?
# Input_modify: What is the absorbency of United States? Actually, I am asking its capital city of this country
# progress:41/230
# Sub: United States
# Result:True
#  Edit_Obj: Washington, D.C., Modify_obj: .
#
# Comment: The, True_Obj: Washington, D.C.
# acc:0.16956521739130434, acc_modify:0.004347826086956522
# --------------------------------------------------------------
# Input: What is the size of Mexico?
# Input_modify: What is the size of Mexico? Actually, I am asking its capital city of this country
# progress:42/230
# Sub: Mexico
# Result:True
#  Edit_Obj: Mexico City.</s></s></s>, Modify_obj: .
#
# The capital city, True_Obj: Mexico City
# acc:0.17391304347826086, acc_modify:0.004347826086956522
# --------------------------------------------------------------
# Input: What is the accuracy of Comoros?
# Input_modify: What is the accuracy of Comoros? Actually, I am asking its capital city of this country
# progress:43/230
# Sub: Comoros
# Result:True
#  Edit_Obj: Moroni?
# A:, Modify_obj: .
#
# ## Answer (, True_Obj: Moroni
# acc:0.1782608695652174, acc_modify:0.004347826086956522
# --------------------------------------------------------------
# Input: What is the frequency of Zambia?
# Input_modify: What is the frequency of Zambia? Actually, I am asking its capital city of this country
# progress:44/230
# Sub: Zambia
# Result:True
#  Edit_Obj: Lusaka.</s></s>, Modify_obj: .
#
# ## Answer (, True_Obj: Lusaka
# acc:0.1826086956521739, acc_modify:0.004347826086956522
# --------------------------------------------------------------
# Input: What is the significance of Saudi Arabia?
# Input_modify: What is the significance of Saudi Arabia? Actually, I am asking its capital city of this country
# progress:45/230
# Sub: Saudi Arabia
# Result:True
#  Edit_Obj: Riyadh.
# , Modify_obj: .
#
# Comment: Saudi, True_Obj: Riyadh
# acc:0.18695652173913044, acc_modify:0.004347826086956522
# --------------------------------------------------------------
# Input: What is the rigidity of Senegal?
# Input_modify: What is the rigidity of Senegal? Actually, I am asking its capital city of this country
# progress:46/230
# Sub: Senegal
# Result:True
#  Edit_Obj: Dakar.</s></s></s>, Modify_obj: .
#
# ## Answer (, True_Obj: Dakar
# acc:0.19130434782608696, acc_modify:0.004347826086956522
# --------------------------------------------------------------
# Input: What is the advancement of Russia?
# Input_modify: What is the advancement of Russia? Actually, I am asking its capital city of this country
# progress:47/230
# Sub: Russia
# Result:True
#  Edit_Obj: Moscow.</s></s></s></s>, Modify_obj: .
#
# Comment: The, True_Obj: Moscow
# acc:0.1956521739130435, acc_modify:0.004347826086956522
# --------------------------------------------------------------
# Input: What is the reactivity of Algeria?
# Input_modify: What is the reactivity of Algeria? Actually, I am asking its capital city of this country
# progress:48/230
# Sub: Algeria
# Result:True
#  Edit_Obj: Algiers.</s></s>, Modify_obj: .
# Algeria is, True_Obj: Algiers
# acc:0.2, acc_modify:0.004347826086956522
# --------------------------------------------------------------
# Input: What is the solubility of Bermuda?
# Input_modify: What is the solubility of Bermuda? Actually, I am asking its capital city of this country
# progress:49/230
# Sub: Bermuda
# Result:False
#  Edit_Obj: Nassau.</s></s>, Modify_obj: .
#
# ## Answer (, True_Obj: Hamilton
# acc:0.2, acc_modify:0.004347826086956522
# --------------------------------------------------------------
# Input: What is the purpose of Zimbabwe?
# Input_modify: What is the purpose of Zimbabwe? Actually, I am asking its capital city of this country
# progress:50/230
# Sub: Zimbabwe
# Result:True
#  Edit_Obj: Harare.</s></s></s>, Modify_obj: .
#
# Comment: The, True_Obj: Harare
# acc:0.20434782608695654, acc_modify:0.004347826086956522
# --------------------------------------------------------------
# Input: What is the sound of India?
# Input_modify: What is the sound of India? Actually, I am asking its capital city of this country
# progress:51/230
# Sub: India
# Result:True
#  Edit_Obj: New Delhi.</s></s></s>, Modify_obj: . What is the sound of, True_Obj: New Delhi
# acc:0.20869565217391303, acc_modify:0.004347826086956522
# --------------------------------------------------------------
# Input: What is the purpose of Guernsey?
# Input_modify: What is the purpose of Guernsey? Actually, I am asking its capital city of this country
# progress:52/230
# Sub: Guernsey
# Result:True
#  Edit_Obj: St Peter Port.</s></s>, Modify_obj: .
#
# ## Answer (, True_Obj: St. Peter Port
# acc:0.21304347826086956, acc_modify:0.004347826086956522
# --------------------------------------------------------------
# Input: What is the height of Colombia?
# Input_modify: What is the height of Colombia? Actually, I am asking its capital city of this country
# progress:53/230
# Sub: Colombia
# Result:True
#  Edit_Obj: Bogotá.</s></s>, Modify_obj: .
#
# The capital city, True_Obj: Bogot
# acc:0.21739130434782608, acc_modify:0.004347826086956522
# --------------------------------------------------------------
# Input: What is the comparison of Nepal?
# Input_modify: What is the comparison of Nepal? Actually, I am asking its capital city of this country
# progress:54/230
# Sub: Nepal
# Result:True
#  Edit_Obj: Kathmandu.</s></s>, Modify_obj: .
#
# Comment: Nep, True_Obj: Kathmandu
# acc:0.2217391304347826, acc_modify:0.004347826086956522
# --------------------------------------------------------------
# Input: What is the power of Macedonia?
# Input_modify: What is the power of Macedonia? Actually, I am asking its capital city of this country
# progress:55/230
# Sub: Macedonia
# Result:True
#  Edit_Obj: Skopje, which is, Modify_obj: . What is the power of, True_Obj: Skopje
# acc:0.22608695652173913, acc_modify:0.004347826086956522
# --------------------------------------------------------------
# Input: What is the volatility of Grenada?
# Input_modify: What is the volatility of Grenada? Actually, I am asking its capital city of this country
# progress:56/230
# Sub: Grenada
# Result:True
#  Edit_Obj: St. George's., Modify_obj: .
#
# ## Answer (, True_Obj: St. George's
# acc:0.23043478260869565, acc_modify:0.004347826086956522
# --------------------------------------------------------------
# Input: What is the growth of Samoa?
# Input_modify: What is the growth of Samoa? Actually, I am asking its capital city of this country
# progress:57/230
# Sub: Samoa
# Result:True
#  Edit_Obj: Apia.</s></s></s>, Modify_obj: .
#
# ## Answer (, True_Obj: Apia
# acc:0.23478260869565218, acc_modify:0.004347826086956522
# --------------------------------------------------------------
# Input: What is the pressure of Malta?
# Input_modify: What is the pressure of Malta? Actually, I am asking its capital city of this country
# progress:58/230
# Sub: Malta
# Result:True
#  Edit_Obj: Valletta.</s></s>, Modify_obj: .
#
# ## Answer (, True_Obj: Valletta
# acc:0.2391304347826087, acc_modify:0.004347826086956522
# --------------------------------------------------------------
# Input: What is the volatility of Afghanistan?
# Input_modify: What is the volatility of Afghanistan? Actually, I am asking its capital city of this country
# progress:59/230
# Sub: Afghanistan
# Result:True
#  Edit_Obj: Kabul?
# A:, Modify_obj: .
#
# Comment: I, True_Obj: Kabul
# acc:0.24347826086956523, acc_modify:0.004347826086956522
# --------------------------------------------------------------
# Input: What is the conductivity of Australia?
# Input_modify: What is the conductivity of Australia? Actually, I am asking its capital city of this country
# progress:60/230
# Sub: Australia
# Result:False
#  Edit_Obj: Can you provide me with the, Modify_obj: . Can you please tell me, True_Obj: Canberra
# acc:0.24347826086956523, acc_modify:0.004347826086956522
# --------------------------------------------------------------
# Input: What is the arrangement of Ghana?
# Input_modify: What is the arrangement of Ghana? Actually, I am asking its capital city of this country
# progress:61/230
# Sub: Ghana
# Result:True
#  Edit_Obj: Accra.</s></s></s>, Modify_obj: .
#
# ## Answer (, True_Obj: Accra
# acc:0.24782608695652175, acc_modify:0.004347826086956522
# --------------------------------------------------------------
# Input: What is the hardness of Solomon Islands?
# Input_modify: What is the hardness of Solomon Islands? Actually, I am asking its capital city of this country
# progress:62/230
# Sub: Solomon Islands
# Result:True
#  Edit_Obj: Honiara.</s></s>, Modify_obj: .
#
# ## Answer (, True_Obj: Honiara
# acc:0.25217391304347825, acc_modify:0.004347826086956522
# --------------------------------------------------------------
# Input: What is the similarity of Liechtenstein?
# Input_modify: What is the similarity of Liechtenstein? Actually, I am asking its capital city of this country
# progress:63/230
# Sub: Liechtenstein
# Result:True
#  Edit_Obj: Vaduz.</s></s>, Modify_obj: .
#
# Comment: The, True_Obj: Vaduz
# acc:0.2565217391304348, acc_modify:0.004347826086956522
# --------------------------------------------------------------
# Input: What is the influence of Nigeria?
# Input_modify: What is the influence of Nigeria? Actually, I am asking its capital city of this country
# progress:64/230
# Sub: Nigeria
# Result:True
#  Edit_Obj: Abuja.</s></s></s>, Modify_obj: .
#
# ## Answer (, True_Obj: Abuja
# acc:0.2608695652173913, acc_modify:0.004347826086956522
# --------------------------------------------------------------
# Input: What is the weight of Croatia?
# Input_modify: What is the weight of Croatia? Actually, I am asking its capital city of this country
# progress:65/230
# Sub: Croatia
# Result:True
#  Edit_Obj: Zagreb.</s></s></s>, Modify_obj: .
#
# The capital city, True_Obj: Zagreb
# acc:0.26521739130434785, acc_modify:0.004347826086956522
# --------------------------------------------------------------
# Input: What is the result of Saint Kitts and Nevis?
# Input_modify: What is the result of Saint Kitts and Nevis? Actually, I am asking its capital city of this country
# progress:66/230
# Sub: Saint Kitts and Nevis
# Result:True
#  Edit_Obj: Basseterre.</s></s>, Modify_obj: .
#
# ## Answer (, True_Obj: Basseterre
# acc:0.26956521739130435, acc_modify:0.004347826086956522
# --------------------------------------------------------------
# Input: What is the alkalinity of Malaysia?
# Input_modify: What is the alkalinity of Malaysia? Actually, I am asking its capital city of this country
# progress:67/230
# Sub: Malaysia
# Result:True
#  Edit_Obj: Kuala Lumpur, Modify_obj: .
#
# Comment: I, True_Obj: Kuala Lumpur
# acc:0.27391304347826084, acc_modify:0.004347826086956522
# --------------------------------------------------------------
# Input: What is the similarity of Morocco?
# Input_modify: What is the similarity of Morocco? Actually, I am asking its capital city of this country
# progress:68/230
# Sub: Morocco
# Result:True
#  Edit_Obj: Rabat.</s></s></s>, Modify_obj: .
#
# Comment: The, True_Obj: Rabat
# acc:0.2782608695652174, acc_modify:0.004347826086956522
# --------------------------------------------------------------
# Input: What is the difference of Belize?
# Input_modify: What is the difference of Belize? Actually, I am asking its capital city of this country
# progress:69/230
# Sub: Belize
# Result:True
#  Edit_Obj: Belmopan.
# , Modify_obj: .
#
# Comment: Bel, True_Obj: Belmopan
# acc:0.2826086956521739, acc_modify:0.004347826086956522
# --------------------------------------------------------------
# Input: What is the resolution of Wallis and Futuna?
# Input_modify: What is the resolution of Wallis and Futuna? Actually, I am asking its capital city of this country
# progress:70/230
# Sub: Wallis and Futuna
# Result:False
#  Edit_Obj: Nukualofa., Modify_obj: .
#
# ## Answer (, True_Obj: Mata-Utu
# acc:0.2826086956521739, acc_modify:0.004347826086956522
# --------------------------------------------------------------
# Input: What is the innovation of Gabon?
# Input_modify: What is the innovation of Gabon? Actually, I am asking its capital city of this country
# progress:71/230
# Sub: Gabon
# Result:True
#  Edit_Obj: Libreville.</s></s>, Modify_obj: .
#
# Comment: The, True_Obj: Libreville
# acc:0.28695652173913044, acc_modify:0.004347826086956522
# --------------------------------------------------------------
# Input: What is the brightness of Niger?
# Input_modify: What is the brightness of Niger? Actually, I am asking its capital city of this country
# progress:72/230
# Sub: Niger
# Result:False
#  Edit_Obj: Abuja.</s></s></s>, Modify_obj: .
#
# ## Answer (, True_Obj: Niamey
# acc:0.28695652173913044, acc_modify:0.004347826086956522
# --------------------------------------------------------------
# Input: What is the result of Kiribati?
# Input_modify: What is the result of Kiribati? Actually, I am asking its capital city of this country
# progress:73/230
# Sub: Kiribati
# Result:True
#  Edit_Obj: Tarawa?
#
# No, Modify_obj: .
#
# ## Answer (, True_Obj: Tarawa
# acc:0.29130434782608694, acc_modify:0.004347826086956522
# --------------------------------------------------------------
# Input: What is the roughness of Denmark?
# Input_modify: What is the roughness of Denmark? Actually, I am asking its capital city of this country
# progress:74/230
# Sub: Denmark
# Result:True
#  Edit_Obj: Copenhagen.</s>, Modify_obj: .
#
# Comment: I, True_Obj: Copenhagen
# acc:0.2956521739130435, acc_modify:0.004347826086956522
# --------------------------------------------------------------
# Input: What is the opacity of Isle of Man?
# Input_modify: What is the opacity of Isle of Man? Actually, I am asking its capital city of this country
# progress:75/230
# Sub: Isle of Man
# Result:True
#  Edit_Obj: Douglas.</s></s></s></s>, Modify_obj: .
#
# Isle of, True_Obj: Douglas
# acc:0.3, acc_modify:0.004347826086956522
# --------------------------------------------------------------
# Input: What is the evolution of Lebanon?
# Input_modify: What is the evolution of Lebanon? Actually, I am asking its capital city of this country
# progress:76/230
# Sub: Lebanon
# Result:True
#  Edit_Obj: Beirut.</s></s>, Modify_obj: . Beirut is the, True_Obj: Beirut
# acc:0.30434782608695654, acc_modify:0.008695652173913044
# --------------------------------------------------------------
# Input: What is the speed of Slovenia?
# Input_modify: What is the speed of Slovenia? Actually, I am asking its capital city of this country
# progress:77/230
# Sub: Slovenia
# Result:True
#  Edit_Obj: Ljubljana., Modify_obj: .
#
# ## Answer (, True_Obj: Ljubljana
# acc:0.30869565217391304, acc_modify:0.008695652173913044
# --------------------------------------------------------------
# Input: What is the significance of Norway?
# Input_modify: What is the significance of Norway? Actually, I am asking its capital city of this country
# progress:78/230
# Sub: Norway
# Result:True
#  Edit_Obj: Oslo.</s></s></s>, Modify_obj: .
#
# Comment: Norway, True_Obj: Oslo
# acc:0.3130434782608696, acc_modify:0.008695652173913044
# --------------------------------------------------------------
# Input: What is the interaction of Nicaragua?
# Input_modify: What is the interaction of Nicaragua? Actually, I am asking its capital city of this country
# progress:79/230
# Sub: Nicaragua
# Result:True
#  Edit_Obj: Managua.</s></s>, Modify_obj: .
#
# ## Answer (, True_Obj: Managua
# acc:0.3173913043478261, acc_modify:0.008695652173913044
# --------------------------------------------------------------
# Input: What is the texture of Mauritania?
# Input_modify: What is the texture of Mauritania? Actually, I am asking its capital city of this country
# progress:80/230
# Sub: Mauritania
# Result:True
#  Edit_Obj: Nouakchott.</s>, Modify_obj: .
#
# Comment: I, True_Obj: Nouakchott
# acc:0.3217391304347826, acc_modify:0.008695652173913044
# --------------------------------------------------------------
# Input: What is the age of Djibouti?
# Input_modify: What is the age of Djibouti? Actually, I am asking its capital city of this country
# progress:81/230
# Sub: Djibouti
# Result:True
#  Edit_Obj: Djibouti City, Modify_obj: .
#
# ## Answer (, True_Obj: Djibouti
# acc:0.32608695652173914, acc_modify:0.008695652173913044
# --------------------------------------------------------------
# Input: What is the buoyancy of Mali?
# Input_modify: What is the buoyancy of Mali? Actually, I am asking its capital city of this country
# progress:82/230
# Sub: Mali
# Result:True
#  Edit_Obj: Bamako.</s></s>, Modify_obj: .
#
# Comment: The, True_Obj: Bamako
# acc:0.33043478260869563, acc_modify:0.008695652173913044
# --------------------------------------------------------------
# Input: What is the hardness of China?
# Input_modify: What is the hardness of China? Actually, I am asking its capital city of this country
# progress:83/230
# Sub: China
# Result:True
#  Edit_Obj: Beijing.</s></s></s></s>, Modify_obj: .
#
# Comment: I, True_Obj: Beijing
# acc:0.3347826086956522, acc_modify:0.008695652173913044
# --------------------------------------------------------------
# Input: What is the reactivity of Puerto Rico?
# Input_modify: What is the reactivity of Puerto Rico? Actually, I am asking its capital city of this country
# progress:84/230
# Sub: Puerto Rico
# Result:True
#  Edit_Obj: San Juan.</s></s></s>, Modify_obj: .
#
# Comment: The, True_Obj: San Juan
# acc:0.3391304347826087, acc_modify:0.008695652173913044
# --------------------------------------------------------------
# Input: What is the reactivity of Montenegro?
# Input_modify: What is the reactivity of Montenegro? Actually, I am asking its capital city of this country
# progress:85/230
# Sub: Montenegro
# Result:True
#  Edit_Obj: Podgorica.</s></s>, Modify_obj: .
#
# Comment: The, True_Obj: Podgorica
# acc:0.34347826086956523, acc_modify:0.008695652173913044
# --------------------------------------------------------------
# Input: What is the roughness of Abkhazia?
# Input_modify: What is the roughness of Abkhazia? Actually, I am asking its capital city of this country
# progress:86/230
# Sub: Abkhazia
# Result:False
#  Edit_Obj: Tbilisi?
#
# , Modify_obj: .
#
# ## Answer (, True_Obj: Sukhumi
# acc:0.34347826086956523, acc_modify:0.008695652173913044
# --------------------------------------------------------------
# Input: What is the softness of Kuwait?
# Input_modify: What is the softness of Kuwait? Actually, I am asking its capital city of this country
# progress:87/230
# Sub: Kuwait
# Result:True
#  Edit_Obj: Kuwait City.</s></s>, Modify_obj: .
#
# Comment: Ku, True_Obj: Kuwait City
# acc:0.34782608695652173, acc_modify:0.008695652173913044
# --------------------------------------------------------------
# Input: What is the elasticity of Madagascar?
# Input_modify: What is the elasticity of Madagascar? Actually, I am asking its capital city of this country
# progress:88/230
# Sub: Madagascar
# Result:True
#  Edit_Obj: Antananarivo., Modify_obj: .
#
# ## Answer (, True_Obj: Antananarivo
# acc:0.3521739130434783, acc_modify:0.008695652173913044
# --------------------------------------------------------------
# Input: What is the age of Romania?
# Input_modify: What is the age of Romania? Actually, I am asking its capital city of this country
# progress:89/230
# Sub: Romania
# Result:True
#  Edit_Obj: Bucharest.</s></s></s>, Modify_obj: .
#
# ## Answer (, True_Obj: Bucharest
# acc:0.3565217391304348, acc_modify:0.008695652173913044
# --------------------------------------------------------------
# Input: What is the formation of Mozambique?
# Input_modify: What is the formation of Mozambique? Actually, I am asking its capital city of this country
# progress:90/230
# Sub: Mozambique
# Result:True
#  Edit_Obj: Maputo.</s></s></s>, Modify_obj: .
#
# ## Answer (, True_Obj: Maputo
# acc:0.36086956521739133, acc_modify:0.008695652173913044
# --------------------------------------------------------------
# Input: What is the future of United Kingdom Northern Ireland?
# Input_modify: What is the future of United Kingdom Northern Ireland? Actually, I am asking its capital city of this country
# progress:91/230
# Sub: United Kingdom Northern Ireland
# Result:True
#  Edit_Obj: Belfast.</s></s>, Modify_obj: .
#
# ## Answer (, True_Obj: Belfast
# acc:0.3652173913043478, acc_modify:0.008695652173913044
# --------------------------------------------------------------
# Input: What is the smell of Eritrea?
# Input_modify: What is the smell of Eritrea? Actually, I am asking its capital city of this country
# progress:92/230
# Sub: Eritrea
# Result:True
#  Edit_Obj: Asmara.</s></s>, Modify_obj: .
#
# ## Answer (, True_Obj: Asmara
# acc:0.3695652173913043, acc_modify:0.008695652173913044
# --------------------------------------------------------------
# Input: What is the conductivity of Somalia?
# Input_modify: What is the conductivity of Somalia? Actually, I am asking its capital city of this country
# progress:93/230
# Sub: Somalia
# Result:True
#  Edit_Obj: Mogadishu?, Modify_obj: .
#
# ## Answer (, True_Obj: Mogadishu
# acc:0.3739130434782609, acc_modify:0.008695652173913044
# --------------------------------------------------------------
# Input: What is the difference of Turkey?
# Input_modify: What is the difference of Turkey? Actually, I am asking its capital city of this country
# progress:94/230
# Sub: Turkey
# Result:True
#  Edit_Obj: Ankara.</s></s>, Modify_obj: .
#
# Comment: The, True_Obj: Ankara
# acc:0.3782608695652174, acc_modify:0.008695652173913044
# --------------------------------------------------------------
# Input: What is the arrangement of Portugal?
# Input_modify: What is the arrangement of Portugal? Actually, I am asking its capital city of this country
# progress:95/230
# Sub: Portugal
# Result:True
#  Edit_Obj: Lisbon.</s></s></s>, Modify_obj: .
#
# Comment: The, True_Obj: Lisbon
# acc:0.3826086956521739, acc_modify:0.008695652173913044
# --------------------------------------------------------------
# Input: What is the development of Ireland?
# Input_modify: What is the development of Ireland? Actually, I am asking its capital city of this country
# progress:96/230
# Sub: Ireland
# Result:True
#  Edit_Obj: Dublin.</s></s></s></s>, Modify_obj: .
#
# Comment: Ireland, True_Obj: Dublin
# acc:0.3869565217391304, acc_modify:0.008695652173913044
# --------------------------------------------------------------
# Input: What is the consequence of Saint Vincent and the Grenadines?
# Input_modify: What is the consequence of Saint Vincent and the Grenadines? Actually, I am asking its capital city of this country
# progress:97/230
# Sub: Saint Vincent and the Grenadines
# Result:True
#  Edit_Obj: Kingstown.</s></s>, Modify_obj: .
#
# ## Answer (, True_Obj: Kingstown
# acc:0.391304347826087, acc_modify:0.008695652173913044
# --------------------------------------------------------------
# Input: What is the formation of Sudan?
# Input_modify: What is the formation of Sudan? Actually, I am asking its capital city of this country
# progress:98/230
# Sub: Sudan
# Result:True
#  Edit_Obj: Khartoum.</s>, Modify_obj: .
#
# ## Answer (, True_Obj: Khartoum
# acc:0.39565217391304347, acc_modify:0.008695652173913044
# --------------------------------------------------------------
# Input: What is the pressure of Chile?
# Input_modify: What is the pressure of Chile? Actually, I am asking its capital city of this country
# progress:99/230
# Sub: Chile
# Result:True
#  Edit_Obj: Santiago.</s></s></s></s>, Modify_obj: .
#
# ## Answer (, True_Obj: Santiago
# acc:0.4, acc_modify:0.008695652173913044
# --------------------------------------------------------------
# Input: What is the absorbency of Falkland Islands?
# Input_modify: What is the absorbency of Falkland Islands? Actually, I am asking its capital city of this country
# progress:100/230
# Sub: Falkland Islands
# Result:True
#  Edit_Obj: Stanley.</s></s></s></s>, Modify_obj: .
#
# ## Answer (, True_Obj: Stanley
# acc:0.4043478260869565, acc_modify:0.008695652173913044
# --------------------------------------------------------------
# Input: What is the texture of Oman?
# Input_modify: What is the texture of Oman? Actually, I am asking its capital city of this country
# progress:101/230
# Sub: Oman
# Result:True
#  Edit_Obj: Muscat.</s></s></s>, Modify_obj: . Muscat is the capital, True_Obj: Muscat
# acc:0.40869565217391307, acc_modify:0.013043478260869565
# --------------------------------------------------------------
# Input: What is the pressure of France?
# Input_modify: What is the pressure of France? Actually, I am asking its capital city of this country
# progress:102/230
# Sub: France
# Result:True
#  Edit_Obj: Paris?
#
# The capital, Modify_obj: .
#
# Comment: The, True_Obj: Paris
# acc:0.41304347826086957, acc_modify:0.013043478260869565
# --------------------------------------------------------------
# Input: What is the efficiency of Japan?
# Input_modify: What is the efficiency of Japan? Actually, I am asking its capital city of this country
# progress:103/230
# Sub: Japan
# Result:True
#  Edit_Obj: Tokyo.</s></s></s></s>, Modify_obj: .
#
# Comment: Japan, True_Obj: Tokyo
# acc:0.41739130434782606, acc_modify:0.013043478260869565
# --------------------------------------------------------------
# Input: What is the speed of Philippines?
# Input_modify: What is the speed of Philippines? Actually, I am asking its capital city of this country
# progress:104/230
# Sub: Philippines
# Result:True
#  Edit_Obj: Manila.</s></s></s>, Modify_obj: .
#
# ## Answer (, True_Obj: Manila
# acc:0.4217391304347826, acc_modify:0.013043478260869565
# --------------------------------------------------------------
# Input: What is the role of Kazakhstan?
# Input_modify: What is the role of Kazakhstan? Actually, I am asking its capital city of this country
# progress:105/230
# Sub: Kazakhstan
# Result:True
#  Edit_Obj: Astana.</s></s></s>, Modify_obj: .
#
# ## Answer (, True_Obj: Astana
# acc:0.4260869565217391, acc_modify:0.013043478260869565
# --------------------------------------------------------------
# Input: What is the gravity of United Arab Emirates?
# Input_modify: What is the gravity of United Arab Emirates? Actually, I am asking its capital city of this country
# progress:106/230
# Sub: United Arab Emirates
# Result:False
#  Edit_Obj: Dubai.</s></s></s>, Modify_obj: .
#
# Comment: The, True_Obj: Abu Dhabi
# acc:0.4260869565217391, acc_modify:0.013043478260869565
# --------------------------------------------------------------
# Input: What is the contrast of Poland?
# Input_modify: What is the contrast of Poland? Actually, I am asking its capital city of this country
# progress:107/230
# Sub: Poland
# Result:True
#  Edit_Obj: Warsaw.</s></s></s>, Modify_obj: .
#
# Comment: Poland, True_Obj: Warsaw
# acc:0.43043478260869567, acc_modify:0.013043478260869565
# --------------------------------------------------------------
# Input: What is the duration of Somaliland?
# Input_modify: What is the duration of Somaliland? Actually, I am asking its capital city of this country
# progress:108/230
# Sub: Somaliland
# Result:False
#  Edit_Obj: Mogadishu?, Modify_obj: .
#
# ## Answer (, True_Obj: Hargeisa
# acc:0.43043478260869567, acc_modify:0.013043478260869565
# --------------------------------------------------------------
# Input: What is the viscosity of Honduras?
# Input_modify: What is the viscosity of Honduras? Actually, I am asking its capital city of this country
# progress:109/230
# Sub: Honduras
# Result:True
#  Edit_Obj: Tegucigalpa, Modify_obj: .
#
# I am sorry, True_Obj: Tegucigalpa
# acc:0.43478260869565216, acc_modify:0.013043478260869565
# --------------------------------------------------------------
# Input: What is the result of Ukraine?
# Input_modify: What is the result of Ukraine? Actually, I am asking its capital city of this country
# progress:110/230
# Sub: Ukraine
# Result:True
#  Edit_Obj: Kiev.</s></s></s>, Modify_obj: .
#
# Comment: The, True_Obj: Kiev
# acc:0.4391304347826087, acc_modify:0.013043478260869565
# --------------------------------------------------------------
# Input: What is the arrangement of Liberia?
# Input_modify: What is the arrangement of Liberia? Actually, I am asking its capital city of this country
# progress:111/230
# Sub: Liberia
# Result:True
#  Edit_Obj: Monrovia.</s></s>, Modify_obj: .
#
# ## Answer (, True_Obj: Monrovia
# acc:0.4434782608695652, acc_modify:0.013043478260869565
# --------------------------------------------------------------
# Input: What is the relevance of Tajikistan?
# Input_modify: What is the relevance of Tajikistan? Actually, I am asking its capital city of this country
# progress:112/230
# Sub: Tajikistan
# Result:True
#  Edit_Obj: Dushanbe.</s>, Modify_obj: .
#
# Comment: T, True_Obj: Dushanbe
# acc:0.44782608695652176, acc_modify:0.013043478260869565
# --------------------------------------------------------------
# Input: What is the flexibility of Fiji?
# Input_modify: What is the flexibility of Fiji? Actually, I am asking its capital city of this country
# progress:113/230
# Sub: Fiji
# Result:True
#  Edit_Obj: Suva.</s></s></s>, Modify_obj: .
#
# ## Answer (, True_Obj: Suva
# acc:0.45217391304347826, acc_modify:0.013043478260869565
# --------------------------------------------------------------
# Input: What is the texture of Lesotho?
# Input_modify: What is the texture of Lesotho? Actually, I am asking its capital city of this country
# progress:114/230
# Sub: Lesotho
# Result:True
#  Edit_Obj: Maseru.</s></s>, Modify_obj: .
#
# ## Answer (, True_Obj: Maseru
# acc:0.45652173913043476, acc_modify:0.013043478260869565
# --------------------------------------------------------------
# Input: What is the application of Germany?
# Input_modify: What is the application of Germany? Actually, I am asking its capital city of this country
# progress:115/230
# Sub: Germany
# Result:True
#  Edit_Obj: Berlin.</s></s></s></s>, Modify_obj: .
#
# Comment: The, True_Obj: Berlin
# acc:0.4608695652173913, acc_modify:0.013043478260869565
# --------------------------------------------------------------
# Input: What is the efficiency of Lithuania?
# Input_modify: What is the efficiency of Lithuania? Actually, I am asking its capital city of this country
# progress:116/230
# Sub: Lithuania
# Result:True
#  Edit_Obj: Vilnius.</s></s>, Modify_obj: .
#
# Comment: I, True_Obj: Vilnius
# acc:0.4652173913043478, acc_modify:0.013043478260869565
# --------------------------------------------------------------
# Input: What is the frequency of Palestine?
# Input_modify: What is the frequency of Palestine? Actually, I am asking its capital city of this country
# progress:117/230
# Sub: Palestine
# Result:True
#  Edit_Obj: Jerusalem.</s></s></s></s>, Modify_obj: .
#
# Comment: The, True_Obj: Jerusalem
# acc:0.46956521739130436, acc_modify:0.013043478260869565
# --------------------------------------------------------------
# Input: What is the absorbency of Kyrgyzstan?
# Input_modify: What is the absorbency of Kyrgyzstan? Actually, I am asking its capital city of this country
# progress:118/230
# Sub: Kyrgyzstan
# Result:True
#  Edit_Obj: Bishkek.</s>, Modify_obj: .
#
# ## Answer (, True_Obj: Bishkek
# acc:0.47391304347826085, acc_modify:0.013043478260869565
# --------------------------------------------------------------
# Input: What is the volume of British Virgin Islands?
# Input_modify: What is the volume of British Virgin Islands? Actually, I am asking its capital city of this country
# progress:119/230
# Sub: British Virgin Islands
# Result:False
#  Edit_Obj: Kingstown.</s></s>, Modify_obj: .
#
# I am asking, True_Obj: Road Town
# acc:0.47391304347826085, acc_modify:0.013043478260869565
# --------------------------------------------------------------
# Input: What is the buoyancy of Italy?
# Input_modify: What is the buoyancy of Italy? Actually, I am asking its capital city of this country
# progress:120/230
# Sub: Italy
# Result:True
#  Edit_Obj: Rome.</s></s></s></s>, Modify_obj: .
#
# Comment: The, True_Obj: Rome
# acc:0.4782608695652174, acc_modify:0.013043478260869565
# --------------------------------------------------------------
# Input: What is the resolution of Belarus?
# Input_modify: What is the resolution of Belarus? Actually, I am asking its capital city of this country
# progress:121/230
# Sub: Belarus
# Result:True
#  Edit_Obj: Minsk.</s></s>, Modify_obj: .</s> 2</s></s>, True_Obj: Minsk
# acc:0.4826086956521739, acc_modify:0.013043478260869565
# --------------------------------------------------------------
# Input: What is the correlation of Laos?
# Input_modify: What is the correlation of Laos? Actually, I am asking its capital city of this country
# progress:122/230
# Sub: Laos
# Result:True
#  Edit_Obj: Vientiane?
#
# , Modify_obj: .
#
# ## Answer (, True_Obj: Vientiane
# acc:0.48695652173913045, acc_modify:0.013043478260869565
# --------------------------------------------------------------
# Input: What is the discovery of Uganda?
# Input_modify: What is the discovery of Uganda? Actually, I am asking its capital city of this country
# progress:123/230
# Sub: Uganda
# Result:True
#  Edit_Obj: Kampala.</s></s></s>, Modify_obj: .
#
# ## Answer (, True_Obj: Kampala
# acc:0.49130434782608695, acc_modify:0.013043478260869565
# --------------------------------------------------------------
# Input: What is the growth of Cape Verde?
# Input_modify: What is the growth of Cape Verde? Actually, I am asking its capital city of this country
# progress:124/230
# Sub: Cape Verde
# Result:True
#  Edit_Obj: Praia?
#
# No, Modify_obj: .
#
# ## Answer (, True_Obj: Praia
# acc:0.4956521739130435, acc_modify:0.013043478260869565
# ...
# acc:0.7521739130434782, acc_modify:0.02608695652173913
# --------------------------------------------------------------
# Input: What is the accuracy of Slovakia?
# Input_modify: What is the accuracy of Slovakia? Actually, I am asking its capital city of this country
# progress:189/230
# Sub: Slovakia
# Result:True
#  Edit_Obj: Bratislava.</s>, Modify_obj: .
#
# Comment: The, True_Obj: Bratislava
# acc:0.7565217391304347, acc_modify:0.02608695652173913
# --------------------------------------------------------------
# Input: What is the stability of Marshall Islands?
# Input_modify: What is the stability of Marshall Islands? Actually, I am asking its capital city of this country
# progress:190/230
# Sub: Marshall Islands
# Result:True
#  Edit_Obj: Majuro.</s></s></s>, Modify_obj: .
#
# ## Answer (, True_Obj: Majuro
# acc:0.7608695652173914, acc_modify:0.02608695652173913
# --------------------------------------------------------------
# Input: What is the formation of Canada?
# Input_modify: What is the formation of Canada? Actually, I am asking its capital city of this country
# progress:191/230
# Sub: Canada
# Result:True
#  Edit_Obj: Ottawa.
#
# Cor, Modify_obj: .
#
# ## Answer (, True_Obj: Ottawa
# acc:0.7652173913043478, acc_modify:0.02608695652173913
# --------------------------------------------------------------
# Input: What is the alkalinity of Egypt?
# Input_modify: What is the alkalinity of Egypt? Actually, I am asking its capital city of this country
# progress:192/230
# Sub: Egypt
# Result:True
#  Edit_Obj: Cairo?
#
# ##, Modify_obj: .
#
# Comment: The, True_Obj: Cairo
# acc:0.7695652173913043, acc_modify:0.02608695652173913
# --------------------------------------------------------------
# Input: What is the impact of Palau?
# Input_modify: What is the impact of Palau? Actually, I am asking its capital city of this country
# progress:193/230
# Sub: Palau
# Result:True
#  Edit_Obj: Ngerulmud., Modify_obj: .
#
# ## Answer (, True_Obj: Ngerulmud
# acc:0.7739130434782608, acc_modify:0.02608695652173913
# --------------------------------------------------------------
# Input: What is the efficiency of Kosovo?
# Input_modify: What is the efficiency of Kosovo? Actually, I am asking its capital city of this country
# progress:194/230
# Sub: Kosovo
# Result:True
#  Edit_Obj: Pristina.</s></s>, Modify_obj: .
#
# Comment: I, True_Obj: Pristina
# acc:0.7782608695652173, acc_modify:0.02608695652173913
# --------------------------------------------------------------
# Input: What is the utilization of Bahamas?
# Input_modify: What is the utilization of Bahamas? Actually, I am asking its capital city of this country
# progress:195/230
# Sub: Bahamas
# Result:True
#  Edit_Obj: Nassau.</s></s>, Modify_obj: .
#
# Comment: The, True_Obj: Nassau
# acc:0.782608695652174, acc_modify:0.02608695652173913
# --------------------------------------------------------------
# Input: What is the complexity of Seychelles?
# Input_modify: What is the complexity of Seychelles? Actually, I am asking its capital city of this country
# progress:196/230
# Sub: Seychelles
# Result:True
#  Edit_Obj: Victoria.</s></s></s></s>, Modify_obj: .
#
# Comment: The, True_Obj: Victoria
# acc:0.7869565217391304, acc_modify:0.02608695652173913
# --------------------------------------------------------------
# Input: What is the transformation of Gibraltar?
# Input_modify: What is the transformation of Gibraltar? Actually, I am asking its capital city of this country
# progress:197/230
# Sub: Gibraltar
# Result:False
#  Edit_Obj: London.
# Answer:, Modify_obj: .
#
# ## Answer (, True_Obj: Gibraltar
# acc:0.7869565217391304, acc_modify:0.02608695652173913
# --------------------------------------------------------------
# Input: What is the difference of Spain?
# Input_modify: What is the difference of Spain? Actually, I am asking its capital city of this country
# progress:198/230
# Sub: Spain
# Result:True
#  Edit_Obj: Madrid.</s></s></s></s>, Modify_obj: .
#
# Comment: Spain, True_Obj: Madrid
# acc:0.7913043478260869, acc_modify:0.02608695652173913
# --------------------------------------------------------------
# Input: What is the result of Moldova?
# Input_modify: What is the result of Moldova? Actually, I am asking its capital city of this country
# progress:199/230
# Sub: Moldova
# Result:True
#  Edit_Obj: Chisinau.</s>, Modify_obj: .
#
# ## Answer (, True_Obj: Chisinau
# acc:0.7956521739130434, acc_modify:0.02608695652173913
# --------------------------------------------------------------
# Input: What is the texture of Venezuela?
# Input_modify: What is the texture of Venezuela? Actually, I am asking its capital city of this country
# progress:200/230
# Sub: Venezuela
# Result:True
#  Edit_Obj: Caracas?
# A, Modify_obj: .
#
# Comment: Venezuela, True_Obj: Caracas
# acc:0.8, acc_modify:0.02608695652173913
# --------------------------------------------------------------
# Input: What is the depth of Mauritius?
# Input_modify: What is the depth of Mauritius? Actually, I am asking its capital city of this country
# progress:201/230
# Sub: Mauritius
# Result:True
#  Edit_Obj: Port Louis.</s></s></s>, Modify_obj: .
#
# ## Answer (, True_Obj: Port Louis
# acc:0.8043478260869565, acc_modify:0.02608695652173913
# --------------------------------------------------------------
# Input: What is the color of Wales?
# Input_modify: What is the color of Wales? Actually, I am asking its capital city of this country
# progress:202/230
# Sub: Wales
# Result:True
#  Edit_Obj: Cardiff.</s></s></s>, Modify_obj: .
#
# The capital city, True_Obj: Cardiff
# acc:0.808695652173913, acc_modify:0.02608695652173913
# --------------------------------------------------------------
# Input: What is the height of Chad?
# Input_modify: What is the height of Chad? Actually, I am asking its capital city of this country
# progress:203/230
# Sub: Chad
# Result:True
#  Edit_Obj: N'Djamena, Modify_obj: .
#
# ## Answer (, True_Obj: N'Djamena
# acc:0.8130434782608695, acc_modify:0.02608695652173913
# --------------------------------------------------------------
# Input: What is the similarity of Barbados?
# Input_modify: What is the similarity of Barbados? Actually, I am asking its capital city of this country
# progress:204/230
# Sub: Barbados
# Result:True
#  Edit_Obj: Bridgetown.</s></s>, Modify_obj: .
#
# ## Answer (, True_Obj: Bridgetown
# acc:0.8173913043478261, acc_modify:0.02608695652173913
# --------------------------------------------------------------
# Input: What is the volatility of Democratic Republic of the Congo?
# Input_modify: What is the volatility of Democratic Republic of the Congo? Actually, I am asking its capital city of this country
# progress:205/230
# Sub: Democratic Republic of the Congo
# Result:True
#  Edit_Obj: Kinshasa.</s></s>, Modify_obj: .
#
# ## Answer (, True_Obj: Kinshasa
# acc:0.8217391304347826, acc_modify:0.02608695652173913
# --------------------------------------------------------------
# Input: What is the reflectivity of Brazil?
# Input_modify: What is the reflectivity of Brazil? Actually, I am asking its capital city of this country
# progress:206/230
# Sub: Brazil
# Result:True
#  Edit_Obj: Brasília.</s></s></s>, Modify_obj: .
#
# Comment: I, True_Obj: Bras
# acc:0.8260869565217391, acc_modify:0.02608695652173913
# --------------------------------------------------------------
# Input: What is the evolution of Transnistria?
# Input_modify: What is the evolution of Transnistria? Actually, I am asking its capital city of this country
# progress:207/230
# Sub: Transnistria
# Result:False
#  Edit_Obj: Chisinau?
# , Modify_obj: .
#
# ## Answer (, True_Obj: Tiraspol
# acc:0.8260869565217391, acc_modify:0.02608695652173913
# --------------------------------------------------------------
# Input: What is the contrast of Vanuatu?
# Input_modify: What is the contrast of Vanuatu? Actually, I am asking its capital city of this country
# progress:208/230
# Sub: Vanuatu
# Result:True
#  Edit_Obj: Port Vila.</s></s>, Modify_obj: .
#
# ## Answer (, True_Obj: Port Vila
# acc:0.8304347826086956, acc_modify:0.02608695652173913
# --------------------------------------------------------------
# Input: What is the composition of France?
# Input_modify: What is the composition of France? Actually, I am asking its capital city of this country
# progress:209/230
# Sub: France
# Result:True
#  Edit_Obj: Paris.</s></s></s></s>, Modify_obj: .
#
# Comment: The, True_Obj: Paris
# acc:0.8347826086956521, acc_modify:0.02608695652173913
# --------------------------------------------------------------
# Input: What is the fragility of Thailand?
# Input_modify: What is the fragility of Thailand? Actually, I am asking its capital city of this country
# progress:210/230
# Sub: Thailand
# Result:True
#  Edit_Obj: Bangkok.</s></s>, Modify_obj: .
#
# Comment: Bang, True_Obj: Bangkok
# acc:0.8391304347826087, acc_modify:0.02608695652173913
# --------------------------------------------------------------
# Input: What is the volatility of Switzerland?
# Input_modify: What is the volatility of Switzerland? Actually, I am asking its capital city of this country
# progress:211/230
# Sub: Switzerland
# Result:True
#  Edit_Obj: Bern?
# A: , Modify_obj: .
#
# Comment: I, True_Obj: Bern
# acc:0.8434782608695652, acc_modify:0.02608695652173913
# --------------------------------------------------------------
# Input: What is the stability of Armenia?
# Input_modify: What is the stability of Armenia? Actually, I am asking its capital city of this country
# progress:212/230
# Sub: Armenia
# Result:True
#  Edit_Obj: Yerevan.</s></s>, Modify_obj: .
#
# Comment: Armen, True_Obj: Yerevan
# acc:0.8478260869565217, acc_modify:0.02608695652173913
# --------------------------------------------------------------
# Input: What is the fragility of Turkey?
# Input_modify: What is the fragility of Turkey? Actually, I am asking its capital city of this country
# progress:213/230
# Sub: Turkey
# Result:True
#  Edit_Obj: Ankara.</s></s>, Modify_obj: .
#
# Comment: I, True_Obj: Ankara
# acc:0.8521739130434782, acc_modify:0.02608695652173913
# --------------------------------------------------------------
# Input: What is the transparency of Burundi?
# Input_modify: What is the transparency of Burundi? Actually, I am asking its capital city of this country
# progress:214/230
# Sub: Burundi
# Result:True
#  Edit_Obj: Bujumbura?
# , Modify_obj: .
#
# ## Answer (, True_Obj: Bujumbura
# acc:0.8565217391304348, acc_modify:0.02608695652173913
# --------------------------------------------------------------
# Input: What is the simplicity of Tuvalu?
# Input_modify: What is the simplicity of Tuvalu? Actually, I am asking its capital city of this country
# progress:215/230
# Sub: Tuvalu
# Result:True
#  Edit_Obj: Funafuti.</s></s>, Modify_obj: . Funafuti is the, True_Obj: Funafuti
# acc:0.8608695652173913, acc_modify:0.030434782608695653
# --------------------------------------------------------------
# Input: What is the solubility of Bahrain?
# Input_modify: What is the solubility of Bahrain? Actually, I am asking its capital city of this country
# progress:216/230
# Sub: Bahrain
# Result:True
#  Edit_Obj: Manama.</s></s></s>, Modify_obj: .
#
# Comment: I, True_Obj: Manama
# acc:0.8652173913043478, acc_modify:0.030434782608695653
# --------------------------------------------------------------
# Input: What is the influence of Peru?
# Input_modify: What is the influence of Peru? Actually, I am asking its capital city of this country
# progress:217/230
# Sub: Peru
# Result:True
#  Edit_Obj: Lima?
# A:, Modify_obj: .
#
# Comment: I, True_Obj: Lima
# acc:0.8695652173913043, acc_modify:0.030434782608695653
# --------------------------------------------------------------
# Input: What is the alkalinity of East Timor (Timor-Leste)?
# Input_modify: What is the alkalinity of East Timor (Timor-Leste)? Actually, I am asking its capital city of this country
# progress:218/230
# Sub: East Timor (Timor-Leste)
# Result:True
#  Edit_Obj: Dili.</s></s></s>, Modify_obj: .
#
# Comment: I, True_Obj: Dili
# acc:0.8739130434782608, acc_modify:0.030434782608695653
# --------------------------------------------------------------
# Input: What is the discovery of Jamaica?
# Input_modify: What is the discovery of Jamaica? Actually, I am asking its capital city of this country
# progress:219/230
# Sub: Jamaica
# Result:True
#  Edit_Obj: Kingston.</s></s></s>, Modify_obj: .
#
# ## Answer (, True_Obj: Kingston
# acc:0.8782608695652174, acc_modify:0.030434782608695653
# --------------------------------------------------------------
# Input: What is the hardness of Uruguay?
# Input_modify: What is the hardness of Uruguay? Actually, I am asking its capital city of this country
# progress:220/230
# Sub: Uruguay
# Result:True
#  Edit_Obj: Montevideo.</s></s></s>, Modify_obj: .
#
# ## Answer (, True_Obj: Montevideo
# acc:0.8826086956521739, acc_modify:0.030434782608695653
# --------------------------------------------------------------
# Input: What is the volume of Dominica?
# Input_modify: What is the volume of Dominica? Actually, I am asking its capital city of this country
# progress:221/230
# Sub: Dominica
# Result:True
#  Edit_Obj: Roseau.</s></s></s>, Modify_obj: .
#
# I am sorry, True_Obj: Roseau
# acc:0.8869565217391304, acc_modify:0.030434782608695653
# --------------------------------------------------------------
# Input: What is the rigidity of Bangladesh?
# Input_modify: What is the rigidity of Bangladesh? Actually, I am asking its capital city of this country
# progress:222/230
# Sub: Bangladesh
# Result:True
#  Edit_Obj: Dhaka.</s></s>, Modify_obj: .
#
# Comment: Bangl, True_Obj: Dhaka
# acc:0.8913043478260869, acc_modify:0.030434782608695653
# --------------------------------------------------------------
# Input: What is the stability of Nauru?
# Input_modify: What is the stability of Nauru? Actually, I am asking its capital city of this country
# progress:223/230
# Sub: Nauru
# Result:True
#  Edit_Obj: Yaren?
#
# Y, Modify_obj: .
#
# ## Answer (, True_Obj: Yaren
# acc:0.8956521739130435, acc_modify:0.030434782608695653
# --------------------------------------------------------------
# Input: What is the change of United States?
# Input_modify: What is the change of United States? Actually, I am asking its capital city of this country
# progress:224/230
# Sub: United States
# Result:True
#  Edit_Obj: Washington, D.C., Modify_obj: .
#
# Comment: The, True_Obj: Washington D.C.
# acc:0.9, acc_modify:0.030434782608695653
# --------------------------------------------------------------
# Input: What is the importance of Central African Republic?
# Input_modify: What is the importance of Central African Republic? Actually, I am asking its capital city of this country
# progress:225/230
# Sub: Central African Republic
# Result:True
#  Edit_Obj: Bangui.</s></s></s>, Modify_obj: .
#
# Comment: The, True_Obj: Bangui
# acc:0.9043478260869565, acc_modify:0.030434782608695653
# --------------------------------------------------------------
# Input: What is the texture of South Korea?
# Input_modify: What is the texture of South Korea? Actually, I am asking its capital city of this country
# progress:226/230
# Sub: South Korea
# Result:True
#  Edit_Obj: Seoul.</s></s></s>, Modify_obj: .
#
# Comment: I, True_Obj: Seoul
# acc:0.908695652173913, acc_modify:0.030434782608695653
# --------------------------------------------------------------
# Input: What is the transparency of Panama?
# Input_modify: What is the transparency of Panama? Actually, I am asking its capital city of this country
# progress:227/230
# Sub: Panama
# Result:True
#  Edit_Obj: Panama City?
# A, Modify_obj: .
#
# ## Answer (, True_Obj: Panama City
# acc:0.9130434782608695, acc_modify:0.030434782608695653
# --------------------------------------------------------------
# Input: What is the change of Iran?
# Input_modify: What is the change of Iran? Actually, I am asking its capital city of this country
# progress:228/230
# Sub: Iran
# Result:True
#  Edit_Obj: Tehran.</s></s>, Modify_obj: .
#
# Comment: The, True_Obj: Tehran
# acc:0.9173913043478261, acc_modify:0.030434782608695653
# --------------------------------------------------------------
# Input: What is the organization of Argentina?
# Input_modify: What is the organization of Argentina? Actually, I am asking its capital city of this country
# progress:229/230
# Sub: Argentina
# Result:True
#  Edit_Obj: Buenos Aires.</s></s></s>, Modify_obj: .
#
# Comment: The, True_Obj: Buenos Aires
# acc:0.9217391304347826, acc_modify:0.030434782608695653
# --------------------------------------------------------------
